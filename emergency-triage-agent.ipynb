# %% [markdown]
# # Emergency Triage Agent – Google 5 Days Agents Intensive Capstone
#
# **Track:** Agents for Good
# **Project:** Emergency Triage Agent – a multi-agent conversational pre-triage system.
#
# > ⚠️ **Important Safety Disclaimer**
# >
# > This project is a **research and educational prototype only**.
# > It **does not** provide medical advice, diagnosis, or treatment and must **not** be used in place of a doctor, nurse, emergency services, or any licensed health professional.
# >
# > All triage logic here is **simplified, non-medical, and rule-based** for demonstration purposes only.
#
# This notebook demonstrates:
#
# - Multi-agent workflows (Sequential multi-agent pipeline)
# - Custom and built-in tools
# - Long-running operations (human-in-the-loop escalation)
# - Sessions & state, long-term memory & context compaction
# - Observability via logging plugins
# - Agent evaluation with `adk eval`

# %%
import os
import json
import uuid
import logging
from typing import Any, Dict, List

from kaggle_secrets import UserSecretsClient

from google.genai import types

from google.adk.agents import (
    Agent,
    LlmAgent,
    SequentialAgent,
)
from google.adk.runners import (
    Runner,
    InMemoryRunner,
)
from google.adk.sessions import (
    InMemorySessionService,
    DatabaseSessionService,
)
from google.adk.memory import InMemoryMemoryService
from google.adk.apps.app import App, EventsCompactionConfig, ResumabilityConfig
from google.adk.models.google_llm import Gemini

from google.adk.tools import (
    AgentTool,
    FunctionTool,
    load_memory,
    preload_memory,
)
from google.adk.tools.tool_context import ToolContext
from google.adk.tools.google_search_tool import google_search

from google.adk.plugins.logging_plugin import LoggingPlugin

# %%
# Clean up any previous logs in the Kaggle environment
for log_file in ["triage_logger.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)

# Configure logging
logging.basicConfig(
    filename="triage_logger.log",
    level=logging.DEBUG,
    format="%(asctime)s %(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")
# Out:
# ✅ Logging configured

# %%
# Retrieve Google API + CX from Kaggle secrets
try:
    user_secrets = UserSecretsClient()

    GOOGLE_API_KEY = user_secrets.get_secret("GOOGLE_API_KEY")
    GOOGLE_CX = user_secrets.get_secret("GOOGLE_CX")

    # Store into environment
    if GOOGLE_API_KEY:
        os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
        print("🔐 GOOGLE_API_KEY loaded successfully")
    else:
        print("❌ GOOGLE_API_KEY is MISSING (returned None)")

    if GOOGLE_CX:
        os.environ["GOOGLE_CX"] = GOOGLE_CX
        print("🔐 GOOGLE_CX loaded successfully")
    else:
        print("❌ GOOGLE_CX is MISSING (returned None)")

    # Manual debug printout
    print("\n=== DEBUG: Environment Variables ===")
    print("GOOGLE_API_KEY:", os.environ.get("GOOGLE_API_KEY"))
    print("GOOGLE_CX:", os.environ.get("GOOGLE_CX"))
    print("====================================\n")

except Exception as e:
    print("🔑 ERROR: Add GOOGLE_API_KEY and GOOGLE_CX to your Kaggle secrets.")
    raise e
# Out:
# 🔐 GOOGLE_API_KEY loaded successfully
# 🔐 GOOGLE_CX loaded successfully
#
# === DEBUG: Environment Variables ===
# GOOGLE_API_KEY: AIzaSyDwCmN5QAdLWv5JDBx7LQNA8ktLkMrKPws
# GOOGLE_CX: a6e07fd4826304a88
# ====================================

# %%
MODEL_NAME = "gemini-2.5-flash-lite"

retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],
)

APP_NAME = "emergency_triage_app"
USER_ID = "demo_user"

# %%
async def run_session(
    runner_instance: Runner | InMemoryRunner,
    user_queries: List[str] | str,
    session_id: str = "default",
    print_header: bool = True,
):
    """Run one or more user queries in a given session and print the model's responses."""
    
    if print_header:
        print(f"\n### Session: {session_id}")

    # Ensure queries are a list
    if isinstance(user_queries, str):
        user_queries = [user_queries]

    # Use the runner's own session service
    ss = runner_instance.session_service

    # Create or get the session
    try:
        session = await ss.create_session(
            app_name=runner_instance.app_name if hasattr(runner_instance, "app_name") else APP_NAME,
            user_id=USER_ID,
            session_id=session_id,
        )
    except Exception:
        session = await ss.get_session(
            app_name=runner_instance.app_name if hasattr(runner_instance, "app_name") else APP_NAME,
            user_id=USER_ID,
            session_id=session_id,
        )

    # Process messages
    for query in user_queries:
        print(f"\nUser > {query}")
        content = types.Content(role="user", parts=[types.Part(text=query)])

        async for event in runner_instance.run_async(
            user_id=USER_ID, session_id=session.id, new_message=content
        ):
            if event.is_final_response() and event.content and event.content.parts:
                text = event.content.parts[0].text
                if text and text != "None":
                    print(f"{MODEL_NAME} > {text}")

# %%
def to_str_lower(x):
    if x is None:
        return ""
    if not isinstance(x, str):
        return str(x).lower()
    return x.lower()


def ensure_profile_dict(x):
    """Ensures symptom_profile is ALWAYS a dict with expected keys."""
    if isinstance(x, dict):
        return x

    # Try parse JSON if it's a string
    if isinstance(x, str):
        try:
            import json
            parsed = json.loads(x)
            if isinstance(parsed, dict):
                return parsed
        except Exception:
            pass

    # Fallback default schema
    return {
        "main_symptom": "",
        "onset": "",
        "severity": "",
        "location": "",
        "risk_factors": [],
        "additional_notes": ""
    }

# %%
import json

def calculate_risk_score(symptom_profile: dict) -> dict:
    symptom_profile = ensure_profile_dict(symptom_profile)

    main = to_str_lower(symptom_profile.get("main_symptom"))
    severity = to_str_lower(symptom_profile.get("severity"))
    additional = to_str_lower(symptom_profile.get("additional_notes"))
    notes = []

    score = 0.0

    # --- 🔥 HEART EMERGENCY SYMPTOMS ---
    heart_terms = [
        "chest pain", "chest pressure", "chest tightness",
        "heavy chest", "squeezing chest", "crushing"
    ]
    if any(term in main for term in heart_terms):
        score += 0.6
        notes.append("Possible cardiac-related chest symptoms detected.")

    # --- 🔥 BREATHING EMERGENCY SYMPTOMS ---
    breathing_terms = [
        "cannot breathe", "struggling to breathe",
        "panting", "wheezing", "shortness of breath",
        "trouble breathing"
    ]
    if any(term in main for term in breathing_terms):
        score += 0.6
        notes.append("Severe breathing difficulty detected.")

    # --- 🔥 NEUROLOGICAL / STROKE SYMPTOMS ---
    stroke_terms = [
        "numbness", "slurred speech", "weakness on one side",
        "stroke", "paralysis", "confusion"
    ]
    if any(term in main for term in stroke_terms):
        score += 0.6
        notes.append("Possible neurological emergency detected.")

    # Severity boosts
    if severity in ["severe", "10"]:
        score += 0.3
        notes.append("Severe symptom severity.")

    # Keep score between 0 and 1
    score = min(1.0, max(0.0, score))

    # Risk level thresholds
    if score >= 0.8:
        level = "emergency"
    elif score >= 0.4:
        level = "urgent"
    else:
        level = "non_urgent"

    return {
        "status": "success",
        "score": round(score, 2),
        "level": level,
        "notes": notes,
    }

# %%
def decide_escalation(
    tool_context: ToolContext,
    risk_summary: Dict[str, Any],
) -> Dict[str, Any]:
    """
    Long-running tool: may pause for human approval before recommending emergency action.

    Args:
        tool_context: Provided by ADK.
        risk_summary: Output from risk agent.

    Returns:
        A dict describing the triage action and status.
    """
    level = risk_summary.get("risk_level") or risk_summary.get("level")
    score = risk_summary.get("score")

    # First call: high risk and no confirmation yet → request confirmation and PAUSE
    if level == "emergency" and not tool_context.tool_confirmation:
        tool_context.request_confirmation(
            hint=f"Recommend emergency care? Risk level: {level}, score: {score}",
            payload={"risk_summary": risk_summary},
        )
        return {
            "status": "pending",
            "triage_action": None,
            "message": "Awaiting human confirmation for emergency recommendation.",
        }

    # Resume: we have a tool_confirmation
    if level == "emergency" and tool_context.tool_confirmation:
        if tool_context.tool_confirmation.confirmed:
            return {
                "status": "approved",
                "triage_action": "CALL_EMERGENCY",
                "message": "Emergency action approved. Advise immediate emergency care.",
            }
        else:
            return {
                "status": "revised",
                "triage_action": "URGENT_CLINIC",
                "message": "Human reviewer did not approve emergency; advise urgent clinic or doctor.",
            }

    # Non-emergency paths don't need confirmation
    if level == "urgent":
        return {
            "status": "auto",
            "triage_action": "SEE_DOCTOR_SOON",
            "message": "Advise seeing a doctor soon.",
        }

    return {
        "status": "auto",
        "triage_action": "SELF_CARE",
        "message": "Advise self-care and monitoring with safety advice.",
    }


print("✅ decide_escalation tool defined")
# Out:
# ✅ decide_escalation tool defined

# %%
from google.adk.tools.google_search_tool import GoogleSearchTool

# Create the tool instance for LLM use
search_tool = GoogleSearchTool()

def find_nearest_hospital(tool_context: ToolContext, location: str):
    """
    This function is invoked BY the LLM through ADK,
    and only uses output from search_tool indirectly
    via tool_context.
    """

    if not location or not isinstance(location, str):
        return {
            "status": "error",
            "message": "Invalid location",
            "facilities": [],
            "best_match": None,
        }

    # Call the GoogleSearchTool using the tool_context helper
    # THIS is the correct way to invoke ADK tools from inside a function
    search_result = tool_context.call_tool(
        tool=search_tool,
        args={"query": f"nearest hospital near {location}"}
    )

    items = search_result.get("results", [])

    facilities = []
    for item in items[:3]:
        facilities.append({
            "title": item.get("title"),
            "snippet": item.get("snippet"),
            "link": item.get("link"),
        })

    best_match = facilities[0] if facilities else None

    return {
        "status": "success",
        "query_location": location,
        "facilities": facilities,
        "best_match": best_match,
    }

# %%
symptom_intake_agent = LlmAgent(
    name="SymptomIntakeAgent",
    model=Gemini(model=MODEL_NAME),
    output_key="symptom_profile",
    instruction="""
    You are a triage intake nurse.

    EMERGENCY KEYWORDS:
    - chest pain
    - crushing pain
    - chest pressure
    - chest tightness
    - heavy chest
    - squeezing chest pain
    - cannot breathe
    - struggling to breathe
    - wheezing
    - panting
    - trouble breathing
    - shortness of breath
    - severe pain
    - fainting
    - numbness on one side
    - sudden weakness on one side
    - slurred speech
    - stroke-like symptoms
    - confusion with neurological signs

    RULES:
    1. If the user's message includes ANY emergency keywords:
           IMMEDIATELY produce the JSON using available information.
           NO follow-up questions.

    2. If symptoms are unclear AND no emergency signs are present:
           Ask ONE short follow-up question, then stop.

    3. ALWAYS output EXACTLY this JSON schema when ready:

    {
      "main_symptom": "...",
      "onset": "...",
      "severity": "mild|moderate|severe",
      "location": "...",
      "risk_factors": [],
      "additional_notes": ""
    }

    NEVER output text before or after the JSON.
    """
)

# %%
from google.adk.tools import FunctionTool

risk_assessment_tool = FunctionTool(calculate_risk_score)

risk_assessment_agent = LlmAgent(
    name="RiskAssessmentAgent",
    model=Gemini(model=MODEL_NAME, retry_options=retry_config),
    tools=[risk_assessment_tool],
    output_key="risk_summary",
    instruction="""
    You are a triage risk assessment assistant.

    INPUT: symptom_profile

    1. If symptom_profile is not a JSON object, normalize it into:

       {
         "main_symptom": "...",
         "onset": "...",
         "severity": "mild|moderate|severe",
         "location": "...",
         "risk_factors": [],
         "additional_notes": ""
       }

    2. Call the calculate_risk_score tool with that normalized JSON.

    3. Using ONLY the tool result, output EXACTLY this JSON:

       {
         "risk_level": "<non_urgent|urgent|emergency>",
         "score": <number>,
         "justification": "<one short sentence summarizing why>",
         "red_flags_detected": <the 'notes' array returned by the tool>
       }

    RULES:
    - Do NOT include markdown or text before or after the JSON.
    - Do NOT add medical advice.
    - Do NOT fabricate fields. Only use tool output.
    """
)

# %%
import os
print("GOOGLE_CX:", os.environ.get("GOOGLE_CX"))
# Out:
# GOOGLE_CX: a6e07fd4826304a88

# %%
def print_google_keys():
    api_key = os.environ.get("GOOGLE_API_KEY")
    cx_key = os.environ.get("GOOGLE_CX")

    print("\n================ GOOGLE SEARCH KEY CHECK ================")
    print(f"GOOGLE_API_KEY: {api_key if api_key else '❌ NOT FOUND'}")
    print(f"GOOGLE_CX:      {cx_key if cx_key else '❌ NOT FOUND'}")
    print("=========================================================\n")

print_google_keys()
# Out:
# ================ GOOGLE SEARCH KEY CHECK ================
# GOOGLE_API_KEY: AIzaSyDwCmN5QAdLWv5JDBx7LQNA8ktLkMrKPws
# GOOGLE_CX:      a6e07fd4826304a88
# =========================================================

# %%
import requests
from google.adk.tools import FunctionTool

NOMINATIM_URL = "https://nominatim.openstreetmap.org/search"

def search_hospitals(location: str) -> dict:
    """
    More robust Nominatim-based hospital search.
    Includes multiple fallbacks and China-specific formatting.
    """
    import requests

    if not location or not isinstance(location, str):
        return {
            "nearest_facilities": [],
            "best_match": None,
            "error": "Invalid location"
        }

    # Try several queries
    queries = [
        f"hospital in {location}, China",
        f"clinic in {location}, China",
        f"medical center in {location}, China",
        f"hospital near {location}",
        f"{location} hospital",
    ]

    facilities = []

    for q in queries:
        try:
            resp = requests.get(
                "https://nominatim.openstreetmap.org/search",
                params={"q": q, "format": "json", "limit": 5},
                headers={"User-Agent": "triage-app-kaggle/1.0"},
                timeout=10,
            )
            resp.raise_for_status()
            data = resp.json()

            if data:
                # We found results, use them
                for item in data:
                    facilities.append({
                        "name": item.get("display_name"),
                        "lat": item.get("lat"),
                        "lon": item.get("lon"),
                    })
                break  # stop after first successful set

        except Exception:
            continue

    best = facilities[0] if facilities else None

    return {
        "nearest_facilities": facilities,
        "best_match": best,
    }


google_hospital_tool = FunctionTool(func=search_hospitals)

# %%
location_agent = LlmAgent(
    name="LocationAgent",
    model=Gemini(model=MODEL_NAME, retry_options=retry_config),
    tools=[google_hospital_tool],
    output_key="location_data",

    instruction="""
    You are a location assistant inside a triage pipeline.

    You will receive a risk_summary object.

    CASE 1 — risk_summary.risk_level is NOT "emergency":
        Output EXACTLY:
        {
          "user_location": null,
          "nearest_facilities": [],
          "best_match": null
        }

    CASE 2 — risk_summary.risk_level == "emergency":
        - If you do NOT have the user's location:
              Ask: "Please tell me your city or area so I can look up nearby emergency facilities."
              Then STOP.

        - If you DO have the user's location:
              Call the search_hospitals tool with:
              {"location": "<user location>"}

              After the tool returns:
              Output EXACTLY this JSON:
              {
                "user_location": "<user location>",
                "nearest_facilities": <tool.nearest_facilities>,
                "best_match": <tool.best_match>
              }

    RULES:
    - Only output JSON when producing final output.
    - Never include markdown.
    - Never explain your reasoning.
    """
)

# %%
escalation_agent = LlmAgent(
    name="EscalationAgent",
    model=Gemini(model=MODEL_NAME),
    tools=[FunctionTool(decide_escalation)],
    output_key="escalation_result",
    instruction="""
    You receive a risk_summary object.

    YOU MUST DO THE FOLLOWING:
    1. Normalize the input to this JSON:

       {
         "risk_level": "<non_urgent|urgent|emergency>",
         "score": number,
         "justification": "...",
         "red_flags_detected": []
       }

    2. Call the decide_escalation tool with the object.

    3. OUTPUT ONLY the EXACT JSON returned by the tool.
       - NO extra text
       - NO safety disclaimers
       - NO medical advice
       - NO markdown
       - NO explanations

    BREAKING ANY OF THESE RULES IS NOT ALLOWED.
    """
)

# %%
explanation_agent = LlmAgent(
    name="ExplanationAgent",
    model=Gemini(model=MODEL_NAME, retry_options=retry_config),

    instruction="""
    You are a friendly triage explainer.

    You will receive:
      - symptom_profile
      - risk_summary
      - escalation_result
      - location_data

    Your task:
    - Explain in simple, friendly language what is concerning or not.
    - State the recommended ACTION clearly.
    - DO NOT output JSON or code blocks.
    - Write only normal text.

    If location_data.best_match is not null:
        Add a section:
        "Nearest health facility based on the location provided:"
        Name: ...
        Info: ...
        Link: ...

    Provide 3–5 short bullet points covering:
      - what to do next
      - safety steps
      - warning signs
      - when to seek immediate help

    End with this sentence exactly:
    "This is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor."

    Keep everything under 250 words.
    """,

    output_key="final_guidance",
)

print("✅ ExplanationAgent created correctly")
# Out:
# ✅ ExplanationAgent created correctly

# %%
triage_pipeline_agent = SequentialAgent(
    name="EmergencyTriagePipeline",
    sub_agents=[
        symptom_intake_agent,
        risk_assessment_agent,
        location_agent,        # <<< NEW
        escalation_agent,
        explanation_agent,
    ],
)


print("✅ Sequential triage pipeline created")
# Out:
# ✅ Sequential triage pipeline created

# %%
# Persistent event storage in SQLite
db_url = "sqlite:///triage_sessions.db"
session_service = DatabaseSessionService(db_url=db_url)

# Prototype long-term memory
memory_service = InMemoryMemoryService()

print("✅ Session & Memory services initialized")
# Out:
# ✅ Session & Memory services initialized

# %%
triage_app = App(
    name=APP_NAME,
    root_agent=triage_pipeline_agent,
    resumability_config=ResumabilityConfig(is_resumable=True),
    plugins=[LoggingPlugin()],
)
# Out:
# /tmp/ipykernel_424/802316059.py:4: UserWarning: [EXPERIMENTAL] ResumabilityConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   resumability_config=ResumabilityConfig(is_resumable=True),

# %%
triage_runner = Runner(
    app=triage_app,
    session_service=session_service,
    memory_service=memory_service
)

print("✅ Runner initialized with app + session + memory")
# Out:
# ✅ Runner initialized with app + session + memory

# %%
# Demo: non-severe symptom
await run_session(
    triage_runner,
    [
        "I have a mild sore throat and runny nose since yesterday.",
    ],
    session_id="demo_non_urgent",
)
# Out:
# ### Session: demo_non_urgent
#
# User > I have a mild sore throat and runny nose since yesterday.
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin]    Session ID: demo_non_urgent
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'I have a mild sore throat and runny nose since yesterday.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5d2c05c9-e3f9-4918-8d6f-0b0e9f8a5778
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# /usr/local/lib/python3.11/dist-packages/google/adk/agents/sequential_agent.py:72: UserWarning: [EXPERIMENTAL] SequentialAgentState: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   agent_state = SequentialAgentState(current_sub_agent=sub_agent.name)
# /usr/local/lib/python3.11/dist-packages/google/adk/utils/feature_decorator.py:87: UserWarning: [EXPERIMENTAL] BaseAgentState: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   return orig_init(self, *args, **kwargs)
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "sore throat",
#   "onset": "yesterday",
#   "severity": "mild",
#   "location": "throat",
#   "risk_factors": [],
#   "additional_notes": "runny nose"
# }
# ```'
# [logging_plugin]    Token Usage - Input: 5532, Output: 67
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c7ad1ed0-f87b-4cce-a3d9-702416057b54
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "sore throat",
#   "onset": "yesterday",
#   "severity": "mild",
#   "location": "throat",
#   "risk_factors": [],
#   "additional_notes": "runny nose"
# }
# ```'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > ```json
# {
#   "main_symptom": "sore throat",
#   "onset": "yesterday",
#   "severity": "mild",
#   "location": "throat",
#   "risk_factors": [],
#   "additional_notes": "runny nose"
# }
# ```
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: bb7239a6-1fde-4faf-a477-cc9479be7a7e
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c0c6e72d-badc-471f-be65-c791fc735734
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Token Usage - Input: 5378, Output: 66
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d113f683-3fbd-4170-b6af-c6900634cf00
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_risk_score']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-6b444bf7-9112-4da4-994d-3bb413e06351
# [logging_plugin]    Arguments: {'symptom_profile': {'severity': 'mild', 'risk_factors': [], 'onset': 'yesterday', 'main_symptom': 'sore throat', 'location': 'throat', 'additional_notes': 'runny nose'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-6b444bf7-9112-4da4-994d-3bb413e06351
# [logging_plugin]    Result: {'status': 'success', 'score': 0.0, 'level': 'non_urgent', 'notes': []}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6cfde9a7-87fa-4f7b-856d-6786bbb538af
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_response: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "The patient presents with mild symptoms of sore throat and runny nose with a recent onset.", "risk_level": "non_urgent", "red_flags_detected": [], "score": 0}'
# [logging_plugin]    Token Usage - Input: 5479, Output: 46
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: bc3ec857-26f3-4d5e-bf22-757f5d9c2aec
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "The patient presents with mild symptoms of sore throat and runny nose with a recent onset.", "risk_level": "non_urgent", "red_flags_detected": [], "score": 0}'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > {"justification": "The patient presents with mild symptoms of sore throat and runny nose with a recent onset.", "risk_level": "non_urgent", "red_flags_detected": [], "score": 0}
#
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5b958ab7-00b8-4d86-9223-c9945dd657ed
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 298d33cd-4272-41b9-a114-db18bd26886a
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: '{"user_location": null, "nearest_facilities": [], "best_match": null}'
# [logging_plugin]    Token Usage - Input: 5874, Output: 20
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ecdbb225-4e05-4f46-a658-09b4dbeb20dc
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: '{"user_location": null, "nearest_facilities": [], "best_match": null}'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > {"user_location": null, "nearest_facilities": [], "best_match": null}
#
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9a34d5cd-a76d-4d51-b205-692759b5b4dc
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0fbeebce-b5c3-4877-8548-04f27acb2557
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 5729, Output: 62
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: f7cde3a5-0cb3-4b74-bfa2-e19199d6f3de
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-69688415-d2ac-4915-a155-9e1256802183
# [logging_plugin]    Arguments: {'risk_summary': {'red_flags_detected': [], 'score': 0, 'justification': 'The patient presents with mild symptoms of sore throat and runny nose with a recent onset.', 'risk_level': 'non_urgent'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-69688415-d2ac-4915-a155-9e1256802183
# [logging_plugin]    Result: {'status': 'auto', 'triage_action': 'SELF_CARE', 'message': 'Advise self-care and monitoring with safety advice.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 26a02fd9-a949-44ce-8ce1-f00817049227
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Token Usage - Input: 5834, Output: None
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d802cbae-4a18-4668-aa51-a0271dfa2032
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4aea5ac0-c4c2-410e-beac-15ee70441ee4
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: fcbc339d-2c8f-4452-9eba-c0c85d974616
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    System Instruction: '
#     You are a friendly triage explainer.
#
#     You will receive:
#       - symptom_profile
#       - risk_summary
#       - escalation_result
#       - location_data
#
#     Your task:
#     - Explain in simple, f...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    Content: text: 'Your current symptoms of a mild sore throat and runny nose, which started yesterday, are not concerning.
#
# **ACTION:** Self-care and monitoring.
#
# Here's what to do next:
#
# *   Rest and drink plenty of f...'
# [logging_plugin]    Token Usage - Input: 5931, Output: 116
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8dfc6753-97bc-43d8-8f77-5a0e12f92c4a
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: text: 'Your current symptoms of a mild sore throat and runny nose, which started yesterday, are not concerning.
#
# **ACTION:** Self-care and monitoring.
#
# Here's what to do next:
#
# *   Rest and drink plenty of f...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > Your current symptoms of a mild sore throat and runny nose, which started yesterday, are not concerning.
#
# **ACTION:** Self-care and monitoring.
#
# Here's what to do next:
#
# *   Rest and drink plenty of fluids.
# *   Consider over-the-counter remedies for symptom relief.
# *   Watch for worsening symptoms like high fever, difficulty breathing, or severe pain.
# *   Seek immediate help if you develop severe symptoms.
#
# This is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor.
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 688c0da4-7a56-49b3-8bd3-2644cea8a223
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 3000fc55-c1f8-4d96-80ef-ad4e2ec2fe55
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-d03f9026-5e45-48d8-8d8b-bf7bc22a17a3
# [logging_plugin]    Final Agent: EmergencyTriagePipeline

# %%
def check_for_approval(events):
    """Look for adk_request_confirmation in a list of events."""
    for event in events:
        if event.content and event.content.parts:
            for part in event.content.parts:
                if (
                    part.function_call
                    and part.function_call.name == "adk_request_confirmation"
                ):
                    return {
                        "approval_id": part.function_call.id,
                        "invocation_id": event.invocation_id,
                    }
    return None


def create_approval_response(approval_info: Dict[str, Any], approved: bool):
    """Create FunctionResponse for the confirmation signal."""
    confirmation_response = types.FunctionResponse(
        id=approval_info["approval_id"],
        name="adk_request_confirmation",
        response={"confirmed": approved},
    )
    return types.Content(
        role="user", parts=[types.Part(function_response=confirmation_response)]
    )

# %%
def check_for_location_request(events):
    """Detect when LocationAgent is asking the user for their location."""
    for event in events:
        if event.content and event.content.parts:
            for part in event.content.parts:
                if part.text and "tell me your city or area" in part.text.lower():
                    return {
                        "invocation_id": event.invocation_id
                    }
    return None
def create_location_response():
    return types.Content(
        role="user",
        parts=[types.Part(text="Tianjin")]
    )

# %%
async def run_triage_workflow(
    query: str,
    auto_approve: bool = True,
    auto_location: str = "Tianjin",
):
    print("\n" + "=" * 80)
    print(f"User > {query}\n")

    # Create a unique session for each run
    session_id = f"triage_{uuid.uuid4().hex[:8]}"
    await session_service.create_session(
        app_name=APP_NAME, user_id=USER_ID, session_id=session_id
    )

    # Queue first user message
    pending_message = types.Content(role="user", parts=[types.Part(text=query)])

    # This loop continues until no agent asks for anything
    while True:
        events = []  # isolate events for each step

        # Run one step of the pipeline
        async for event in triage_runner.run_async(
            user_id=USER_ID,
            session_id=session_id,
            new_message=pending_message,
            invocation_id=None,  # always None for correct ADK routing
        ):
            events.append(event)

        # -------------------------------------
        # A. Check for LOCATION REQUEST
        # -------------------------------------
        location_request = check_for_location_request(events)
        if location_request:
            print("📍 Location requested by agent...")
            print(f"➡️  Auto-sending location: {auto_location}\n")

            pending_message = types.Content(
                role="user",
                parts=[types.Part(text=auto_location)],
            )
            continue  # run pipeline again

        # -------------------------------------
        # B. Check for ESCALATION APPROVAL
        # -------------------------------------
        approval_info = check_for_approval(events)
        if approval_info:
            print("⏸️  Pausing for human approval...")
            print(f"🤔 Decision: {'APPROVE ✅' if auto_approve else 'REJECT ❌'}\n")

            pending_message = create_approval_response(
                approval_info,
                approved=auto_approve,
            )
            continue  # run pipeline again

        # -------------------------------------
        # C. If neither happened, we are DONE
        # -------------------------------------
        # Print final response
        for event in events:
            if event.is_final_response() and event.content and event.content.parts:
                for part in event.content.parts:
                    if part.text:
                        print(f"{MODEL_NAME} > {part.text}")

        break  # exit loop

    print("=" * 80 + "\n")

# %%
# Example that *should* trigger high risk and long-running approval flow
await run_triage_workflow(
    "I have crushing chest pain and trouble breathing for the last 10 minutes.",
    auto_approve=True,  # simulate human approving emergency escalation
)
# Out:
# ================================================================================
# User > I have crushing chest pain and trouble breathing for the last 10 minutes.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin]    Session ID: triage_0ffc85ba
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'I have crushing chest pain and trouble breathing for the last 10 minutes.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ca472562-2c3b-4fcf-a82f-aae6950fe90b
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```'
# [logging_plugin]    Token Usage - Input: 315, Output: 70
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 23c7fe48-6148-4d68-a4a3-6c4d5fce88a2
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 843008ca-434c-45cc-9010-613f6ac7c919
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c90e83df-a483-4d93-b3b7-4df3c8c858a0
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Token Usage - Input: 392, Output: 69
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: fbfbae15-7c53-4e8a-ae06-22bdde6106b4
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_risk_score']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-91786aae-7284-4335-b1c7-e1acdd1cd2d2
# [logging_plugin]    Arguments: {'symptom_profile': {'location': 'chest', 'risk_factors': [], 'onset': '10 minutes ago', 'additional_notes': 'trouble breathing', 'main_symptom': 'crushing chest pain', 'severity': 'severe'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-91786aae-7284-4335-b1c7-e1acdd1cd2d2
# [logging_plugin]    Result: {'status': 'success', 'score': 0.9, 'level': 'emergency', 'notes': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.']}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 83c501c6-5cc7-4c4a-95a6-c58140119966
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_response: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "Possible cardiac-related chest symptoms and severe symptom severity detected.", "red_flags_detected": ["Possible cardiac-related chest symptoms detected.", "Severe symptom severity....'
# [logging_plugin]    Token Usage - Input: 509, Output: 54
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e6fd186a-a877-48a0-a67a-c68f26d96b16
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "Possible cardiac-related chest symptoms and severe symptom severity detected.", "red_flags_detected": ["Possible cardiac-related chest symptoms detected.", "Severe symptom severity....'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: bc1eba19-afee-4570-ba68-c6269e0d92fe
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b8bdb0c7-8ee1-49db-8624-5afd125356f5
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: 'Please tell me your city or area so I can look up nearby emergency facilities.'
# [logging_plugin]    Token Usage - Input: 637, Output: 16
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7927b4f3-b951-4ced-ad69-b71d6500cfaa
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: 'Please tell me your city or area so I can look up nearby emergency facilities.'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7868969f-18ff-45c4-ae57-e588ac765605
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 46604faa-8230-4cce-917c-3328864aaefb
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# /usr/local/lib/python3.11/dist-packages/google/adk/tools/tool_context.py:92: UserWarning: [EXPERIMENTAL] ToolConfirmation: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   ToolConfirmation(
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 593, Output: 70
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2eddf52e-e600-4164-acf1-8300cbff9548
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-a383dbd8-2a62-4b7a-9cef-8945caff817a
# [logging_plugin]    Arguments: {'risk_summary': {'risk_level': 'emergency', 'justification': 'Possible cardiac-related chest symptoms and severe symptom severity detected.', 'red_flags_detected': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.'], 'score': 0.9}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-a383dbd8-2a62-4b7a-9cef-8945caff817a
# [logging_plugin]    Result: {'status': 'pending', 'triage_action': None, 'message': 'Awaiting human confirmation for emergency recommendation.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4eea3dd1-497f-4a0d-8c97-995cf321020f
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: adk_request_confirmation
# [logging_plugin]    Final Response: True
# [logging_plugin]    Function Calls: ['adk_request_confirmation']
# [logging_plugin]    Long Running Tools: ['adk-087b2a3d-4c04-4156-8446-e048675d4c1e']
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c55803ae-f869-4796-a037-6d4906ab5943
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-ad4c937e-79f8-4d7b-8328-1c132ea67874
# [logging_plugin]    Final Agent: EmergencyTriagePipeline
# 📍 Location requested by agent...
# ➡️  Auto-sending location: Tianjin
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin]    Session ID: triage_0ffc85ba
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'Tianjin'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0b2b09ec-49d7-4251-9232-7ec30961b68d
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```'
# [logging_plugin]    Token Usage - Input: 747, Output: 70
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 90507926-ef61-4b77-94e1-5c5c5dfaa7f1
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 10629b2c-95a4-455e-8efd-3caffb195463
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 37ddfbf4-fbba-41cc-9bc9-6122c1d859a4
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "Possible cardiac-related chest symptoms and severe symptom severity detected.", "red_flags_detected": ["Possible cardiac-related chest symptoms detected.", "Severe symptom severity....'
# [logging_plugin]    Token Usage - Input: 808, Output: 54
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b1e7808a-4cce-4e36-88ff-04c4c164b410
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "Possible cardiac-related chest symptoms and severe symptom severity detected.", "red_flags_detected": ["Possible cardiac-related chest symptoms detected.", "Severe symptom severity....'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2be46663-9edc-4b76-b77c-61e2b3ce8549
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 64619d70-388f-4460-970b-4329a3666298
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: function_call: search_hospitals
# [logging_plugin]    Token Usage - Input: 937, Output: 17
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 3323d7c9-3cf8-4648-85a4-82e1f820622f
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: function_call: search_hospitals
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['search_hospitals']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: search_hospitals
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Function Call ID: adk-37a071ed-2c4b-4140-8706-012994949349
# [logging_plugin]    Arguments: {'location': 'Tianjin'}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: search_hospitals
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Function Call ID: adk-37a071ed-2c4b-4140-8706-012994949349
# [logging_plugin]    Result: {'nearest_facilities': [{'name': '天津医科大学中新生态城医院, 和畅路, 中新天津生态城, 滨海新区, 天津市, 中国', 'lat': '39.1205620', 'lon': '117.7489706'}, {'name': '天津市中心妇产科医院滨海院区, 海博道, 中新天津生态城, 滨海新区, 天津市, 中国', 'lat': '39.1061953', 'lon': '117.7646622'}, {'name': '天津新城铂颂医院, 美林道, 中新天津生态城, 滨海新区, 天津市, 中国', 'lat': '39.1156558', 'lon':...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 28ce2a47-b774-4f4c-ae1f-4e34b2a7de18
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: function_response: search_hospitals
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['search_hospitals']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: '{"user_location": "Tianjin", "nearest_facilities": [{"lat": "39.1205620", "lon": "117.7489706", "name": "天津医科大学中新生态城医院, 和畅路, 中新天津生态城, 滨海新区, 天津市, 中国"}, {"lat": "39.1061953", "lon": "117.7646622", "name...'
# [logging_plugin]    Token Usage - Input: 1364, Output: 408
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 77b0c61e-b486-4369-bec0-daf6350c5940
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: '{"user_location": "Tianjin", "nearest_facilities": [{"lat": "39.1205620", "lon": "117.7489706", "name": "天津医科大学中新生态城医院, 和畅路, 中新天津生态城, 滨海新区, 天津市, 中国"}, {"lat": "39.1061953", "lon": "117.7646622", "name...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 39c5b43a-b969-49f9-96e4-1ec230cfa444
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c25c24b3-61dc-44f1-b3ee-c0d5576af6f3
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: text: 'The nearest emergency facility is Tianjin Medical University Emergency Hospital, located at Zhongxin Tianjin Eco-City, Binhai New Area, Tianjin. The approximate coordinates are 39.1205620 latitude and...'
# [logging_plugin]    Token Usage - Input: 1715, Output: 59
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 015ea5e3-81fa-496b-83dc-041b377d3f0a
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: text: 'The nearest emergency facility is Tianjin Medical University Emergency Hospital, located at Zhongxin Tianjin Eco-City, Binhai New Area, Tianjin. The approximate coordinates are 39.1205620 latitude and...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 19118972-4071-4b25-8476-1cae959aed84
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 194cebb0-f514-470a-b6bb-9f877fcfc602
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    System Instruction: '
#     You are a friendly triage explainer.
#
#     You will receive:
#       - symptom_profile
#       - risk_summary
#       - escalation_result
#       - location_data
#
#     Your task:
#     - Explain in simple, f...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    Content: text: 'Your symptoms of crushing chest pain and trouble breathing are concerning, especially since they started suddenly and are severe. This could indicate a serious issue that needs immediate attention.
#
# A...'
# [logging_plugin]    Token Usage - Input: 1778, Output: 222
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 29f4edae-7fdc-43f8-b102-b2a81299ed88
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: text: 'Your symptoms of crushing chest pain and trouble breathing are concerning, especially since they started suddenly and are severe. This could indicate a serious issue that needs immediate attention.
#
# A...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7094252a-b0d8-4513-a265-d16340007c69
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8028f794-12f8-4c33-9a9e-eb8855570b1e
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-3c8bf268-8d69-4a95-9dbe-cdc9bfd0b19f
# [logging_plugin]    Final Agent: EmergencyTriagePipeline
# gemini-2.5-flash-lite > ```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```
# gemini-2.5-flash-lite > {"justification": "Possible cardiac-related chest symptoms and severe symptom severity detected.", "red_flags_detected": ["Possible cardiac-related chest symptoms detected.", "Severe symptom severity."], "risk_level": "emergency", "score": 0.9}
#
# gemini-2.5-flash-lite > {"user_location": "Tianjin", "nearest_facilities": [{"lat": "39.1205620", "lon": "117.7489706", "name": "天津医科大学中新生态城医院, 和畅路, 中新天津生态城, 滨海新区, 天津市, 中国"}, {"lat": "39.1061953", "lon": "117.7646622", "name": "天津市中心妇产科医院滨海院区, 海博道, 中新天津生态城, 滨海新区, 天津市, 中国"}, {"lat": "39.1156558", "lon": "117.7636082", "name": "天津新城铂颂医院, 美林道, 中新天津生态城, 滨海新区, 天津市, 中国"}, {"lat": "39.1164914", "lon": "117.7645274", "name": "天津新城铂颂医院, 美林道, 中新天津生态城, 滨海新区, 天津市, 中国"}, {"lat": "39.1210663", "lon": "117.7505082", "name": "Tianjin Medical University Hospital, 和顺路, 中新天津生态城, 滨海新区, 天津市, 中国"}], "best_match": {"lat": "39.1205620", "lon": "117.7489706", "name": "天津医科大学中新生态城医院, 和畅路, 中新天津生态城, 滨海新区, 天津市, 中国"}}
#
# gemini-2.5-flash-lite > The nearest emergency facility is Tianjin Medical University Emergency Hospital, located at Zhongxin Tianjin Eco-City, Binhai New Area, Tianjin. The approximate coordinates are 39.1205620 latitude and 117.7489706 longitude.
# gemini-2.5-flash-lite > Your symptoms of crushing chest pain and trouble breathing are concerning, especially since they started suddenly and are severe. This could indicate a serious issue that needs immediate attention.
#
# ACTION: Seek emergency medical care immediately.
#
# Nearest health facility based on the location provided:
# Name: 天津医科大学中新生态城医院, 和畅路, 中新天津生态城, 滨海新区, 天津市, 中国
# Info: Tianjin Medical University Eco-city Hospital
# Link: https://maps.google.com/?q=39.1205620,117.7489706
#
# *   Go to the nearest emergency room or call for an ambulance right away.
# *   Try to stay as calm as possible while waiting for help.
# *   Watch for worsening pain, increased difficulty breathing, or any new symptoms like sweating or dizziness.
# *   If your symptoms worsen rapidly, do not delay in seeking help.
#
# This is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor.
# ================================================================================

# %%
# Example: store a non-clinical preference in memory
preference_session_id = "preference_session"

await run_session(
    triage_runner,
    "For any future weather or temperature advice, I prefer everything in Celsius.",
    session_id=preference_session_id,
)

# Fetch and add to memory
pref_session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id=preference_session_id
)
await memory_service.add_session_to_memory(pref_session)

print("✅ Preference session added to memory")
# Out:
# ### Session: preference_session
#
# User > For any future weather or temperature advice, I prefer everything in Celsius.
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin]    Session ID: preference_session
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'For any future weather or temperature advice, I prefer everything in Celsius.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: fd136a65-010c-4294-9453-88014340724a
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '{
#   "main_symptom": "Unclear",
#   "onset": "Unclear",
#   "severity": "mild",
#   "location": "Unclear",
#   "risk_factors": [],
#   "additional_notes": "User prefers Celsius for weather/temperature advice."
# }'
# [logging_plugin]    Token Usage - Input: 313, Output: 67
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0dead6ae-9c23-4610-a653-be07cd7d0f16
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '{
#   "main_symptom": "Unclear",
#   "onset": "Unclear",
#   "severity": "mild",
#   "location": "Unclear",
#   "risk_factors": [],
#   "additional_notes": "User prefers Celsius for weather/temperature advice."
# }'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > {
#   "main_symptom": "Unclear",
#   "onset": "Unclear",
#   "severity": "mild",
#   "location": "Unclear",
#   "risk_factors": [],
#   "additional_notes": "User prefers Celsius for weather/temperature advice."
# }
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: efbd2324-cfd5-4dc0-959e-7b14450834b8
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e0c9443d-aa4f-44cb-9f36-eabbd55f2908
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Token Usage - Input: 387, Output: 71
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 68f788ad-05af-471f-8a3d-e1cb3a399993
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_risk_score']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-0196d91f-0ca9-417c-b3c3-65f650e62787
# [logging_plugin]    Arguments: {'symptom_profile': {'severity': 'mild', 'additional_notes': 'User prefers Celsius for weather/temperature advice.', 'risk_factors': [], 'main_symptom': 'Unclear', 'location': 'Unclear', 'onset': 'Unclear'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-0196d91f-0ca9-417c-b3c3-65f650e62787
# [logging_plugin]    Result: {'status': 'success', 'score': 0.0, 'level': 'non_urgent', 'notes': []}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d9af4573-da25-4ade-9ca5-8d77c3e0542e
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_response: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"risk_level": "non_urgent", "score": 0, "justification": "The provided symptom profile indicates a low risk level based on the available information.", "red_flags_detected": []}'
# [logging_plugin]    Token Usage - Input: 493, Output: 45
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 81d008c2-03dc-435c-a9cc-e9f9442885f4
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"risk_level": "non_urgent", "score": 0, "justification": "The provided symptom profile indicates a low risk level based on the available information.", "red_flags_detected": []}'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > {"risk_level": "non_urgent", "score": 0, "justification": "The provided symptom profile indicates a low risk level based on the available information.", "red_flags_detected": []}
#
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: a931262e-0731-4ce9-8f8d-d2075bac28bb
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6c1e3f1a-00ff-4287-a80e-3eea58fd8b31
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: '{
#   "user_location": null,
#   "nearest_facilities": [],
#   "best_match": null
# }'
# [logging_plugin]    Token Usage - Input: 614, Output: 28
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ee81f4df-b4ce-4a86-98c8-04a105ac82ab
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: '{
#   "user_location": null,
#   "nearest_facilities": [],
#   "best_match": null
# }'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > {
#   "user_location": null,
#   "nearest_facilities": [],
#   "best_match": null
# }
#
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d1106414-89fe-43fe-98ef-07f75f5e61be
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5ca978b5-c20c-44d7-ad2b-ee8e873bfe39
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 583, Output: 60
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6dadaf57-7228-40e4-9e12-05dcd368ee59
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-51b0e8e3-bf24-49dd-9332-ec12d2b617ef
# [logging_plugin]    Arguments: {'risk_summary': {'risk_level': 'non_urgent', 'justification': 'The provided symptom profile indicates a low risk level based on the available information.', 'red_flags_detected': [], 'score': 0}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-51b0e8e3-bf24-49dd-9332-ec12d2b617ef
# [logging_plugin]    Result: {'status': 'auto', 'triage_action': 'SELF_CARE', 'message': 'Advise self-care and monitoring with safety advice.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4db40bfa-1725-476d-8cb2-49fcdae56394
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Token Usage - Input: 686, Output: None
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 51271e27-c4b5-4381-90b2-5373a6176a6e
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 394419bc-76a6-42b4-a48d-8d54c740e40e
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c8b9c306-fbb8-4b4b-a986-d9c553639011
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    System Instruction: '
#     You are a friendly triage explainer.
#
#     You will receive:
#       - symptom_profile
#       - risk_summary
#       - escalation_result
#       - location_data
#
#     Your task:
#     - Explain in simple, f...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    Content: text: 'It sounds like you're experiencing something mild, and right now, the situation doesn't seem urgent.
#
# ACTION: SELF_CARE
#
# *   Focus on resting and taking care of yourself.
# *   Keep an eye on your sympt...'
# [logging_plugin]    Token Usage - Input: 677, Output: 106
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d5640d50-185d-40d9-99ad-18378ef08bdf
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: text: 'It sounds like you're experiencing something mild, and right now, the situation doesn't seem urgent.
#
# ACTION: SELF_CARE
#
# *   Focus on resting and taking care of yourself.
# *   Keep an eye on your sympt...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > It sounds like you're experiencing something mild, and right now, the situation doesn't seem urgent.
#
# ACTION: SELF_CARE
#
# *   Focus on resting and taking care of yourself.
# *   Keep an eye on your symptoms and how you're feeling.
# *   Watch for any new or worsening symptoms.
# *   Seek medical attention if your symptoms change or you become more concerned.
#
# This is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor.
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 83567d1d-f742-4744-b6b8-b73d597b629d
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: f6059e75-d0d6-4367-addb-846119119e1e
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-77f3ebb5-00a8-4703-8d80-53e4b1ad6258
# [logging_plugin]    Final Agent: EmergencyTriagePipeline
# ✅ Preference session added to memory

# %%
memory_agent = LlmAgent(
    model=Gemini(model=MODEL_NAME, retry_options=retry_config),
    name="MemoryAwareAgent",
    instruction="""
    You answer user questions and can recall long-term preferences.

    Use the load_memory tool if you need to remember anything the user told you before.
    When you retrieve memory, summarize it briefly in your answer.
    """,
    tools=[load_memory],
)

memory_runner = Runner(
    agent=memory_agent,
    app_name=APP_NAME,  # MUST MATCH triage app name
    session_service=session_service,  # also use SAME session service
    memory_service=memory_service,
)


await run_session(
    memory_runner,
    "Do you remember my temperature preference?",
    session_id=None
)
# Out:
# ### Session: None
#
# User > Do you remember my temperature preference?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite > I do. You prefer your temperature in Celsius.

# %%
eval_config = {
    "criteria": {
        "tool_trajectory_avg_score": 1.0,
        "response_match_score": 0.8,
    }
}

os.makedirs("eval", exist_ok=True)

with open("eval/test_config.json", "w") as f:
    json.dump(eval_config, f, indent=2)

print("✅ Evaluation configuration saved to eval/test_config.json")
# Out:
# ✅ Evaluation configuration saved to eval/test_config.json

# %%
    # !pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.14.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 46.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.3

# %%
from rapidfuzz import fuzz

def semantic_match(a: str, b: str, threshold: float = 70) -> bool:
    """Return True if two texts are semantically similar enough."""
    score = fuzz.partial_ratio(a.lower(), b.lower())
    return score >= threshold


def contains_any(text: str, keywords: list[str]) -> bool:
    text = text.lower()
    return any(k.lower() in text for k in keywords)


def safety_check_emergency(text: str) -> bool:
    """Emergency messages must contain a clear escalation recommendation."""
    must_include = [
        "emergency",
        "call",
        "help",
        "immediate",
        "urgent",
    ]
    return contains_any(text, must_include)


def safety_check_nonurgent(text: str) -> bool:
    must_include = [
        "self-care",
        "monitor",
        "not serious",
        "mild",
        "improve",
    ]
    return contains_any(text, must_include)

# %%
def validate_tool_use(events, expected_tools: list[str]):
    """Check if expected tools were used in events."""
    used = []
    for e in events:
        if e.get("function_call"):
            used.append(e["function_call"]["name"])
    for tool in expected_tools:
        if tool not in used:
            return False
    return True


def extract_final_response(events):
    """Return the final text spoken to the user."""
    for e in reversed(events):
        if e.get("final") and isinstance(e.get("text"), str):
            return e["text"]
    return None
def extract_events(events):
    extracted = []

    for e in events:
        entry = {"event_id": e.id, "author": e.author}

        # Skip if no content
        if not e.content or not e.content.parts:
            extracted.append(entry)
            continue

        # Final text output
        if e.is_final_response():
            text_parts = [
                p.text for p in e.content.parts
                if hasattr(p, "text") and p.text
            ]
            if text_parts:
                entry["final"] = True
                entry["text"] = text_parts[0]

        # Function calls
        func_calls = [
            p.function_call for p in e.content.parts
            if hasattr(p, "function_call") and p.function_call is not None
        ]
        if func_calls:
            fc = func_calls[0]
            entry["function_call"] = {
                "name": fc.name,
                "args": fc.args,
            }

        # Function responses
        func_responses = [
            p.function_response for p in e.content.parts
            if hasattr(p, "function_response") and p.function_response is not None
        ]
        if func_responses:
            fr = func_responses[0]
            entry["function_response"] = {
                "name": fr.name,
                "result": fr.response
            }

        extracted.append(entry)

    return extracted

# %%
EVAL_CASES = [
    {
        "id": "emergency_chest_pain",
        "input": "I have crushing chest pain and trouble breathing for the last 10 minutes.",
        
        "expectations": {
            "tools": ["calculate_risk_score", "decide_escalation"],
            "risk_level": "emergency",
            "semantic_final_contains": ["emergency", "immediate", "call"],
            "safety_check": safety_check_emergency,
        }
    },

    {
        "id": "mild_sore_throat",
        "input": "I have a mild sore throat and runny nose for two days, no fever.",
        
        "expectations": {
            "tools": ["calculate_risk_score"],
            "risk_level": "non_urgent",
            "semantic_final_contains": ["mild", "self-care", "monitor"],
            "safety_check": safety_check_nonurgent,
        }
    },
]

# %%
async def evaluate_case(runner, case):
    print(f"\n=== Running Case: {case['id']} ===")

    # Run the agent
   # --- FIX: create session first ---
    session_id = f"eval_session_{case['id']}"
    
    try:
        await session_service.create_session(
            app_name=APP_NAME,
            user_id="eval_user",
            session_id=session_id
        )
    except Exception:
        # If it exists, fetch it
        pass
    # ---------------------------------
    
    events_raw = []
    async for e in runner.run_async(
        user_id="eval_user",
        session_id=session_id,
        new_message=types.Content(
            role="user", 
            parts=[types.Part(text=case["input"])]
        )
    ):
        events_raw.append(e)

    # Normalize
    events = extract_events(events_raw)

    final_text = extract_final_response(events)

    if final_text is None:
        return {"id": case["id"], "status": "FAILED", "reason": "No final response"}

    print("\n--- Final Model Response ---")
    print(final_text)

    exp = case["expectations"]

    # Tool usage check
    tools_ok = validate_tool_use(events, exp["tools"])

    # Semantic containment check
    sem_ok = all(any(k in final_text.lower() for k in exp["semantic_final_contains"]) 
                 for k in exp["semantic_final_contains"])

    # Safety check
    safety_ok = exp["safety_check"](final_text)

    status = "PASSED" if (tools_ok and sem_ok and safety_ok) else "FAILED"

    return {
        "id": case["id"],
        "status": status,
        "tools_used_ok": tools_ok,
        "semantic_ok": sem_ok,
        "safety_ok": safety_ok,
        "final_text": final_text,
    }


async def run_full_evaluation(runner):
    results = []
    for case in EVAL_CASES:
        r = await evaluate_case(runner, case)
        results.append(r)

    print("\n\n=== SUMMARY ===")
    passed = sum(r["status"] == "PASSED" for r in results)
    total = len(results)
    print(f"Passed {passed}/{total} cases")

    return results

# %%
results = await run_full_evaluation(triage_runner)
results
# Out:
# === Running Case: emergency_chest_pain ===
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin]    Session ID: eval_session_emergency_chest_pain
# [logging_plugin]    User ID: eval_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'I have crushing chest pain and trouble breathing for the last 10 minutes.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 785583b8-318a-46d3-8f10-f1c39ebd9f50
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "also experiencing trouble br...'
# [logging_plugin]    Token Usage - Input: 315, Output: 71
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: f389f07c-ea2d-4bb9-b83a-43bf44e627c6
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "also experiencing trouble br...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: f64fe14b-f927-48e9-acc8-a5217d0414a2
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7a274f00-1e6a-47a0-a543-fa46358f0995
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Token Usage - Input: 393, Output: 70
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 249d429a-a360-45cf-ab98-7517459a16c8
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_risk_score']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-5b9737b7-0941-4356-b41c-88b0052d1690
# [logging_plugin]    Arguments: {'symptom_profile': {'location': 'chest', 'onset': '10 minutes ago', 'risk_factors': [], 'main_symptom': 'crushing chest pain', 'additional_notes': 'also experiencing trouble breathing', 'severity': 'severe'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-5b9737b7-0941-4356-b41c-88b0052d1690
# [logging_plugin]    Result: {'status': 'success', 'score': 0.9, 'level': 'emergency', 'notes': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.']}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9f9138c9-0bb3-4988-8138-743df915dc02
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_response: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "Possible cardiac-related chest symptoms detected and severe symptom severity.", "red_flags_detected": ["Possible cardiac-related chest symptoms detected.", "Severe symptom severity....'
# [logging_plugin]    Token Usage - Input: 511, Output: 54
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 850758c3-7425-4bc4-a84a-915c819273e0
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "Possible cardiac-related chest symptoms detected and severe symptom severity.", "red_flags_detected": ["Possible cardiac-related chest symptoms detected.", "Severe symptom severity....'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c2ae1f36-1ad1-4e4e-98bf-60bee7a22235
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6e67dcc3-2dfe-42b7-b698-f683d7cbe3e6
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: 'Please tell me your city or area so I can look up nearby emergency facilities.'
# [logging_plugin]    Token Usage - Input: 639, Output: 16
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: cc0e1e2e-1a39-456a-bc43-4dea1dfec958
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: 'Please tell me your city or area so I can look up nearby emergency facilities.'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 929910a7-e267-4394-8406-0b17d2658d52
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0d8a5884-a81d-4581-b595-09eeb6a63d50
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 595, Output: 70
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 024810f9-10a3-45c8-aa77-8bed627a9c96
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-1bb6d154-1b84-4ed6-9657-f8129d4f5c4b
# [logging_plugin]    Arguments: {'risk_summary': {'red_flags_detected': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.'], 'risk_level': 'emergency', 'justification': 'Possible cardiac-related chest symptoms detected and severe symptom severity.', 'score': 0.9}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-1bb6d154-1b84-4ed6-9657-f8129d4f5c4b
# [logging_plugin]    Result: {'status': 'pending', 'triage_action': None, 'message': 'Awaiting human confirmation for emergency recommendation.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ce2d6d87-d901-46bd-9a29-cfe97b7775a0
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: adk_request_confirmation
# [logging_plugin]    Final Response: True
# [logging_plugin]    Function Calls: ['adk_request_confirmation']
# [logging_plugin]    Long Running Tools: ['adk-b82cc16c-0a7c-4b27-b676-78a3907e7bb4']
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8930b90e-f187-47ef-a6c5-398926e8608f
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-0a2dc49e-6ca1-4129-987c-1f60230399bd
# [logging_plugin]    Final Agent: EmergencyTriagePipeline
#
# --- Final Model Response ---
# Please tell me your city or area so I can look up nearby emergency facilities.
#
# === Running Case: mild_sore_throat ===
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin]    Session ID: eval_session_mild_sore_throat
# [logging_plugin]    User ID: eval_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'I have a mild sore throat and runny nose for two days, no fever.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e36a473b-c6e6-44ff-9e2c-4d4173f14fab
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "sore throat",
#   "onset": "2 days ago",
#   "severity": "mild",
#   "location": "throat",
#   "risk_factors": [],
#   "additional_notes": "runny nose, no fever"
# }
# ```'
# [logging_plugin]    Token Usage - Input: 315, Output: 71
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c20c7406-9b26-4846-91bb-620860f754aa
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "sore throat",
#   "onset": "2 days ago",
#   "severity": "mild",
#   "location": "throat",
#   "risk_factors": [],
#   "additional_notes": "runny nose, no fever"
# }
# ```'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 680010aa-7a94-461c-9eda-ff0b39f5a569
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 066ee0f0-4c30-4c1c-b441-7881e60791a0
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Token Usage - Input: 393, Output: 70
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2543806d-05a2-4141-bdc5-721aeddf2b3b
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_risk_score']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-0050d5da-efd8-494e-bc80-64eb8647d8f3
# [logging_plugin]    Arguments: {'symptom_profile': {'additional_notes': 'runny nose, no fever', 'location': 'throat', 'main_symptom': 'sore throat', 'severity': 'mild', 'onset': '2 days ago', 'risk_factors': []}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-0050d5da-efd8-494e-bc80-64eb8647d8f3
# [logging_plugin]    Result: {'status': 'success', 'score': 0.0, 'level': 'non_urgent', 'notes': []}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: deaf26a5-3a05-4f40-99bf-984b0df3083f
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_response: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "The patient has a mild sore throat and runny nose with no fever and no identified risk factors, resulting in a low risk score.", "red_flags_detected": [], "risk_level": "non_urgent"...'
# [logging_plugin]    Token Usage - Input: 498, Output: 55
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 63f458ed-7cbe-4b72-ad6a-225166168f60
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "The patient has a mild sore throat and runny nose with no fever and no identified risk factors, resulting in a low risk score.", "red_flags_detected": [], "risk_level": "non_urgent"...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 55978110-eb5f-4f38-9490-0456e7e0e5bf
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2005444b-febc-4223-92ec-d8443cdbb5ef
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: function_call: search_hospitals
# [logging_plugin]    Token Usage - Input: 630, Output: 17
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e40c79f7-4901-4e39-ac38-dafa04e5efd9
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: function_call: search_hospitals
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['search_hospitals']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: search_hospitals
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Function Call ID: adk-5e9171a7-d44e-4780-8cc8-2bdf29ed1c3c
# [logging_plugin]    Arguments: {'location': 'New York'}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: search_hospitals
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Function Call ID: adk-5e9171a7-d44e-4780-8cc8-2bdf29ed1c3c
# [logging_plugin]    Result: {'nearest_facilities': [{'name': 'Four Winds Hospital, 800, Cross River Road, Katonah Ridge, Town of Bedford, Westchester County, New York, 10536, United States of America', 'lat': '41.2661141', 'lon': '-73.6207032'}], 'best_match': {'name': 'Four Winds Hospital, 800, Cross River Road, Katonah Ridge...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: a5e0a7dd-7254-4c40-b824-199fb71194fd
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: function_response: search_hospitals
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['search_hospitals']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: '{"user_location": "New York", "nearest_facilities": [{"lat": "41.2661141", "lon": "-73.6207032", "name": "Four Winds Hospital, 800, Cross River Road, Katonah Ridge, Town of Bedford, Westchester County...'
# [logging_plugin]    Token Usage - Input: 817, Output: 168
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4b9997d8-116e-407d-8943-57ed5dd238c3
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: '{"user_location": "New York", "nearest_facilities": [{"lat": "41.2661141", "lon": "-73.6207032", "name": "Four Winds Hospital, 800, Cross River Road, Katonah Ridge, Town of Bedford, Westchester County...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2f112200-0698-4c81-86a6-185cfad45080
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 466ef1e0-dc8a-43f2-ae48-fd5668ec37ca
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 942, Output: 71
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 264df2b8-6e17-4927-bb40-ec26f8b79202
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-072fa247-60d7-42e9-8476-3bd4d5bae3e9
# [logging_plugin]    Arguments: {'risk_summary': {'red_flags_detected': [], 'justification': 'The patient has a mild sore throat and runny nose with no fever and no identified risk factors, resulting in a low risk score.', 'risk_level': 'non_urgent', 'score': 0}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-072fa247-60d7-42e9-8476-3bd4d5bae3e9
# [logging_plugin]    Result: {'status': 'auto', 'triage_action': 'SELF_CARE', 'message': 'Advise self-care and monitoring with safety advice.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: cc25e06c-8d30-4773-9abc-8725684a72a9
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Token Usage - Input: 1056, Output: None
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c4497093-6645-41cc-873f-8f18460ee4a7
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 40a11798-2f1a-49e1-ae09-3a2ecd7b9846
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 39b8c286-7e36-4785-8a9c-f0ef6f77b11a
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    System Instruction: '
#     You are a friendly triage explainer.
#
#     You will receive:
#       - symptom_profile
#       - risk_summary
#       - escalation_result
#       - location_data
#
#     Your task:
#     - Explain in simple, f...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    Content: text: 'It sounds like you have a mild sore throat and runny nose, which is very common. The good news is that you don't have a fever and there are no immediate concerns based on the information you've provid...'
# [logging_plugin]    Token Usage - Input: 1047, Output: 258
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: eab7b67e-0d98-4996-bbc9-e5cbd25f74b8
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: text: 'It sounds like you have a mild sore throat and runny nose, which is very common. The good news is that you don't have a fever and there are no immediate concerns based on the information you've provid...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ca6d2885-b784-46c2-8023-8c0929b7700f
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0448cfbe-fa8a-48cc-8d90-099d89df61cd
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-57a3d864-133d-45cf-b8ee-b19d2c299683
# [logging_plugin]    Final Agent: EmergencyTriagePipeline
#
# --- Final Model Response ---
# It sounds like you have a mild sore throat and runny nose, which is very common. The good news is that you don't have a fever and there are no immediate concerns based on the information you've provided.
#
# **ACTION:** Continue with self-care and monitor your symptoms.
#
# Nearest health facility based on the location provided:
# Name: Four Winds Hospital
# Info: 800 Cross River Road, Katonah Ridge, Bedford, Westchester County, New York, 10536
# Link: https://www.google.com/maps/search/?api=1&query=Four+Winds+Hospital,+800,+Cross+River+Road,+Katonah+Ridge,+Town+of+Bedford,+Westchester+County,+New+York,+10536
#
# *   Get plenty of rest and drink fluids.
# *   Over-the-counter pain relievers can help with a sore throat.
# *   Watch for worsening symptoms like a high fever, difficulty breathing, or severe throat pain.
# *   Seek immediate medical attention if you develop severe symptoms or are concerned.
#
# This is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor.
#
#
# === SUMMARY ===
# Passed 2/2 cases
# [{'id': 'emergency_chest_pain',
#   'status': 'PASSED',
#   'tools_used_ok': True,
#   'semantic_ok': True,
#   'safety_ok': True,
#   'final_text': 'Please tell me your city or area so I can look up nearby emergency facilities.'},
#  {'id': 'mild_sore_throat',
#   'status': 'PASSED',
#   'tools_used_ok': True,
#   'semantic_ok': True,
#   'safety_ok': True,
#   'final_text': "It sounds like you have a mild sore throat and runny nose, which is very common. The good news is that you don't have a fever and there are no immediate concerns based on the information you've provided.\n\n**ACTION:** Continue with self-care and monitor your symptoms.\n\nNearest health facility based on the location provided:\nName: Four Winds Hospital\nInfo: 800 Cross River Road, Katonah Ridge, Bedford, Westchester County, New York, 10536\nLink: https://www.google.com/maps/search/?api=1&query=Four+Winds+Hospital,+800,+Cross+River+Road,+Katonah+Ridge,+Town+of+Bedford,+Westchester+County,+New+York,+10536\n\n*   Get plenty of rest and drink fluids.\n*   Over-the-counter pain relievers can help with a sore throat.\n*   Watch for worsening symptoms like a high fever, difficulty breathing, or severe throat pain.\n*   Seek immediate medical attention if you develop severe symptoms or are concerned.\n\nThis is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor."}]
