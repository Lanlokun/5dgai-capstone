# %% [markdown]
# # Emergency Triage Agent – Google 5 Days Agents Intensive Capstone
#
# **Track:** Agents for Good
# **Project:** Emergency Triage Agent – a multi-agent conversational pre-triage system.
#
# > ⚠️ **Important Safety Disclaimer**
# >
# > This project is a **research and educational prototype only**.
# > It **does not** provide medical advice, diagnosis, or treatment and must **not** be used in place of a doctor, nurse, emergency services, or any licensed health professional.
# >
# > All triage logic here is **simplified, non-medical, and rule-based** for demonstration purposes only.
#
# This notebook demonstrates:
#
# - Multi-agent workflows (Sequential multi-agent pipeline)
# - Custom and built-in tools
# - Long-running operations (human-in-the-loop escalation)
# - Sessions & state, long-term memory & context compaction
# - Observability via logging plugins
# - Agent evaluation with `adk eval`

# %%
import os
import json
import uuid
import logging
from typing import Any, Dict, List

from kaggle_secrets import UserSecretsClient

from google.genai import types

from google.adk.agents import (
    Agent,
    LlmAgent,
    SequentialAgent,
)
from google.adk.runners import (
    Runner,
    InMemoryRunner,
)
from google.adk.sessions import (
    InMemorySessionService,
    DatabaseSessionService,
)
from google.adk.memory import InMemoryMemoryService
from google.adk.apps.app import App, EventsCompactionConfig, ResumabilityConfig
from google.adk.models.google_llm import Gemini

from google.adk.tools import (
    AgentTool,
    FunctionTool,
    load_memory,
    preload_memory,
)
from google.adk.tools.tool_context import ToolContext
from google.adk.tools.google_search_tool import google_search

from google.adk.plugins.logging_plugin import LoggingPlugin

# %%
for log_file in ["triage_logger.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)

logging.basicConfig(
    filename="triage_logger.log",
    level=logging.DEBUG,
    format="%(asctime)s %(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")
# Out:
# ✅ Logging configured

# %%
try:
    user_secrets = UserSecretsClient()

    GOOGLE_API_KEY = user_secrets.get_secret("GOOGLE_API_KEY")
    GOOGLE_CX = user_secrets.get_secret("GOOGLE_CX")

    # Store into environment
    if GOOGLE_API_KEY:
        os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
        print("🔐 GOOGLE_API_KEY loaded successfully")
    else:
        print("❌ GOOGLE_API_KEY is MISSING (returned None)")

    if GOOGLE_CX:
        os.environ["GOOGLE_CX"] = GOOGLE_CX
        print("🔐 GOOGLE_CX loaded successfully")
    else:
        print("❌ GOOGLE_CX is MISSING (returned None)")

    print("\n=== DEBUG: Environment Variables ===")
    print("GOOGLE_API_KEY:", os.environ.get("GOOGLE_API_KEY"))
    print("GOOGLE_CX:", os.environ.get("GOOGLE_CX"))
    print("====================================\n")

except Exception as e:
    print("🔑 ERROR: Add GOOGLE_API_KEY and GOOGLE_CX to your Kaggle secrets.")
    raise e
# Out:
# 🔐 GOOGLE_API_KEY loaded successfully
# 🔐 GOOGLE_CX loaded successfully
#
# === DEBUG: Environment Variables ===
# GOOGLE_API_KEY: AIzaSyDwCmN5QAdLWv5JDBx7LQNA8ktLkMrKPws
# GOOGLE_CX: a6e07fd4826304a88
# ====================================

# %%
MODEL_NAME = "gemini-2.5-flash-lite"

retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],
)

APP_NAME = "emergency_triage_app"
USER_ID = "demo_user"

# %%
async def run_session(
    runner_instance: Runner | InMemoryRunner,
    user_queries: List[str] | str,
    session_id: str = "default",
    print_header: bool = True,
):
    """Run one or more user queries in a given session and print the model's responses."""
    
    if print_header:
        print(f"\n### Session: {session_id}")

    if isinstance(user_queries, str):
        user_queries = [user_queries]

    ss = runner_instance.session_service

    try:
        session = await ss.create_session(
            app_name=runner_instance.app_name if hasattr(runner_instance, "app_name") else APP_NAME,
            user_id=USER_ID,
            session_id=session_id,
        )
    except Exception:
        session = await ss.get_session(
            app_name=runner_instance.app_name if hasattr(runner_instance, "app_name") else APP_NAME,
            user_id=USER_ID,
            session_id=session_id,
        )

    # Process messages
    for query in user_queries:
        print(f"\nUser > {query}")
        content = types.Content(role="user", parts=[types.Part(text=query)])

        async for event in runner_instance.run_async(
            user_id=USER_ID, session_id=session.id, new_message=content
        ):
            if event.is_final_response() and event.content and event.content.parts:
                text = event.content.parts[0].text
                if text and text != "None":
                    print(f"{MODEL_NAME} > {text}")

# %%
def to_str_lower(x):
    if x is None:
        return ""
    if not isinstance(x, str):
        return str(x).lower()
    return x.lower()


def ensure_profile_dict(x):
    """Ensures symptom_profile is ALWAYS a dict with expected keys."""
    if isinstance(x, dict):
        return x

    if isinstance(x, str):
        try:
            import json
            parsed = json.loads(x)
            if isinstance(parsed, dict):
                return parsed
        except Exception:
            pass

    # Fallback default schema
    return {
        "main_symptom": "",
        "onset": "",
        "severity": "",
        "location": "",
        "risk_factors": [],
        "additional_notes": ""
    }

# %%
import json

def calculate_risk_score(symptom_profile: dict) -> dict:
    symptom_profile = ensure_profile_dict(symptom_profile)

    main = to_str_lower(symptom_profile.get("main_symptom"))
    severity = to_str_lower(symptom_profile.get("severity"))
    additional = to_str_lower(symptom_profile.get("additional_notes"))
    notes = []

    score = 0.0

    heart_terms = [
        "chest pain", "chest pressure", "chest tightness",
        "heavy chest", "squeezing chest", "crushing"
    ]
    if any(term in main for term in heart_terms):
        score += 0.6
        notes.append("Possible cardiac-related chest symptoms detected.")

    breathing_terms = [
        "cannot breathe", "struggling to breathe",
        "panting", "wheezing", "shortness of breath",
        "trouble breathing"
    ]
    if any(term in main for term in breathing_terms):
        score += 0.6
        notes.append("Severe breathing difficulty detected.")

    stroke_terms = [
        "numbness", "slurred speech", "weakness on one side",
        "stroke", "paralysis", "confusion"
    ]
    if any(term in main for term in stroke_terms):
        score += 0.6
        notes.append("Possible neurological emergency detected.")

    if severity in ["severe", "10"]:
        score += 0.3
        notes.append("Severe symptom severity.")

    # Keep score between 0 and 1
    score = min(1.0, max(0.0, score))

    # Risk level thresholds
    if score >= 0.8:
        level = "emergency"
    elif score >= 0.4:
        level = "urgent"
    else:
        level = "non_urgent"

    return {
        "status": "success",
        "score": round(score, 2),
        "level": level,
        "notes": notes,
    }

# %%
def decide_escalation(
    tool_context: ToolContext,
    risk_summary: Dict[str, Any],
) -> Dict[str, Any]:
    """
    Long-running tool: may pause for human approval before recommending emergency action.

    Args:
        tool_context: Provided by ADK.
        risk_summary: Output from risk agent.

    Returns:
        A dict describing the triage action and status.
    """
    level = risk_summary.get("risk_level") or risk_summary.get("level")
    score = risk_summary.get("score")

    if level == "emergency" and not tool_context.tool_confirmation:
        tool_context.request_confirmation(
            hint=f"Recommend emergency care? Risk level: {level}, score: {score}",
            payload={"risk_summary": risk_summary},
        )
        return {
            "status": "pending",
            "triage_action": None,
            "message": "Awaiting human confirmation for emergency recommendation.",
        }

    if level == "emergency" and tool_context.tool_confirmation:
        if tool_context.tool_confirmation.confirmed:
            return {
                "status": "approved",
                "triage_action": "CALL_EMERGENCY",
                "message": "Emergency action approved. Advise immediate emergency care.",
            }
        else:
            return {
                "status": "revised",
                "triage_action": "URGENT_CLINIC",
                "message": "Human reviewer did not approve emergency; advise urgent clinic or doctor.",
            }

    if level == "urgent":
        return {
            "status": "auto",
            "triage_action": "SEE_DOCTOR_SOON",
            "message": "Advise seeing a doctor soon.",
        }

    return {
        "status": "auto",
        "triage_action": "SELF_CARE",
        "message": "Advise self-care and monitoring with safety advice.",
    }


print("✅ decide_escalation tool defined")
# Out:
# ✅ decide_escalation tool defined

# %%
from google.adk.tools.google_search_tool import GoogleSearchTool

search_tool = GoogleSearchTool()

def find_nearest_hospital(tool_context: ToolContext, location: str):
    """
    This function is invoked BY the LLM through ADK,
    and only uses output from search_tool indirectly
    via tool_context.
    """

    if not location or not isinstance(location, str):
        return {
            "status": "error",
            "message": "Invalid location",
            "facilities": [],
            "best_match": None,
        }

    search_result = tool_context.call_tool(
        tool=search_tool,
        args={"query": f"nearest hospital near {location}"}
    )

    items = search_result.get("results", [])

    facilities = []
    for item in items[:3]:
        facilities.append({
            "title": item.get("title"),
            "snippet": item.get("snippet"),
            "link": item.get("link"),
        })

    best_match = facilities[0] if facilities else None

    return {
        "status": "success",
        "query_location": location,
        "facilities": facilities,
        "best_match": best_match,
    }

# %%
symptom_intake_agent = LlmAgent(
    name="SymptomIntakeAgent",
    model=Gemini(model=MODEL_NAME),
    output_key="symptom_profile",
    instruction="""
    You are a triage intake nurse.

    EMERGENCY KEYWORDS:
    - chest pain
    - crushing pain
    - chest pressure
    - chest tightness
    - heavy chest
    - squeezing chest pain
    - cannot breathe
    - struggling to breathe
    - wheezing
    - panting
    - trouble breathing
    - shortness of breath
    - severe pain
    - fainting
    - numbness on one side
    - sudden weakness on one side
    - slurred speech
    - stroke-like symptoms
    - confusion with neurological signs

    RULES:
    1. If the user's message includes ANY emergency keywords:
           IMMEDIATELY produce the JSON using available information.
           NO follow-up questions.

    2. If symptoms are unclear AND no emergency signs are present:
           Ask ONE short follow-up question, then stop.

    3. ALWAYS output EXACTLY this JSON schema when ready:

    {
      "main_symptom": "...",
      "onset": "...",
      "severity": "mild|moderate|severe",
      "location": "...",
      "risk_factors": [],
      "additional_notes": ""
    }

    NEVER output text before or after the JSON.
    """
)

# %%
from google.adk.tools import FunctionTool

risk_assessment_tool = FunctionTool(calculate_risk_score)

risk_assessment_agent = LlmAgent(
    name="RiskAssessmentAgent",
    model=Gemini(model=MODEL_NAME, retry_options=retry_config),
    tools=[risk_assessment_tool],
    output_key="risk_summary",
    instruction="""
    You are a triage risk assessment assistant.

    INPUT: symptom_profile

    1. If symptom_profile is not a JSON object, normalize it into:

       {
         "main_symptom": "...",
         "onset": "...",
         "severity": "mild|moderate|severe",
         "location": "...",
         "risk_factors": [],
         "additional_notes": ""
       }

    2. Call the calculate_risk_score tool with that normalized JSON.

    3. Using ONLY the tool result, output EXACTLY this JSON:

       {
         "risk_level": "<non_urgent|urgent|emergency>",
         "score": <number>,
         "justification": "<one short sentence summarizing why>",
         "red_flags_detected": <the 'notes' array returned by the tool>
       }

    RULES:
    - Do NOT include markdown or text before or after the JSON.
    - Do NOT add medical advice.
    - Do NOT fabricate fields. Only use tool output.
    """
)

# %%
import requests
from google.adk.tools import FunctionTool

NOMINATIM_URL = "https://nominatim.openstreetmap.org/search"

def search_hospitals(location: str) -> dict:
    """
    More robust Nominatim-based hospital search.
    Includes multiple fallbacks and China-specific formatting.
    """
    import requests

    if not location or not isinstance(location, str):
        return {
            "nearest_facilities": [],
            "best_match": None,
            "error": "Invalid location"
        }

    queries = [
        f"hospital in {location}, China",
        f"clinic in {location}, China",
        f"medical center in {location}, China",
        f"hospital near {location}",
        f"{location} hospital",
    ]

    facilities = []

    for q in queries:
        try:
            resp = requests.get(
                "https://nominatim.openstreetmap.org/search",
                params={"q": q, "format": "json", "limit": 5},
                headers={"User-Agent": "triage-app-kaggle/1.0"},
                timeout=10,
            )
            resp.raise_for_status()
            data = resp.json()

            if data:
                # We found results, use them
                for item in data:
                    facilities.append({
                        "name": item.get("display_name"),
                        "lat": item.get("lat"),
                        "lon": item.get("lon"),
                    })
                break  # stop after first successful set

        except Exception:
            continue

    best = facilities[0] if facilities else None

    return {
        "nearest_facilities": facilities,
        "best_match": best,
    }


google_hospital_tool = FunctionTool(func=search_hospitals)

# %%
location_agent = LlmAgent(
    name="LocationAgent",
    model=Gemini(model=MODEL_NAME, retry_options=retry_config),
    tools=[google_hospital_tool],
    output_key="location_data",

    instruction="""
    You are a location assistant inside a triage pipeline.

    You will receive a risk_summary object.

    CASE 1 — risk_summary.risk_level is NOT "emergency":
        Output EXACTLY:
        {
          "user_location": null,
          "nearest_facilities": [],
          "best_match": null
        }

    CASE 2 — risk_summary.risk_level == "emergency":
        - If you do NOT have the user's location:
              Ask: "Please tell me your city or area so I can look up nearby emergency facilities."
              Then STOP.

        - If you DO have the user's location:
              Call the search_hospitals tool with:
              {"location": "<user location>"}

              After the tool returns:
              Output EXACTLY this JSON:
              {
                "user_location": "<user location>",
                "nearest_facilities": <tool.nearest_facilities>,
                "best_match": <tool.best_match>
              }

    RULES:
    - Only output JSON when producing final output.
    - Never include markdown.
    - Never explain your reasoning.
    """
)

# %%
escalation_agent = LlmAgent(
    name="EscalationAgent",
    model=Gemini(model=MODEL_NAME),
    tools=[FunctionTool(decide_escalation)],
    output_key="escalation_result",
    instruction="""
    You receive a risk_summary object.

    YOU MUST DO THE FOLLOWING:
    1. Normalize the input to this JSON:

       {
         "risk_level": "<non_urgent|urgent|emergency>",
         "score": number,
         "justification": "...",
         "red_flags_detected": []
       }

    2. Call the decide_escalation tool with the object.

    3. OUTPUT ONLY the EXACT JSON returned by the tool.
       - NO extra text
       - NO safety disclaimers
       - NO medical advice
       - NO markdown
       - NO explanations

    BREAKING ANY OF THESE RULES IS NOT ALLOWED.
    """
)

# %%
explanation_agent = LlmAgent(
    name="ExplanationAgent",
    model=Gemini(model=MODEL_NAME, retry_options=retry_config),

    instruction="""
    You are a friendly triage explainer.

    You will receive:
      - symptom_profile
      - risk_summary
      - escalation_result
      - location_data

    Your task:
    - Explain in simple, friendly language what is concerning or not.
    - State the recommended ACTION clearly.
    - DO NOT output JSON or code blocks.
    - Write only normal text.

    If location_data.best_match is not null:
        Add a section:
        "Nearest health facility based on the location provided:"
        Name: ...
        Info: ...
        Link: ...

    Provide 3–5 short bullet points covering:
      - what to do next
      - safety steps
      - warning signs
      - when to seek immediate help

    End with this sentence exactly:
    "This is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor."

    Keep everything under 250 words.
    """,

    output_key="final_guidance",
)

print("✅ ExplanationAgent created correctly")
# Out:
# ✅ ExplanationAgent created correctly

# %%
triage_pipeline_agent = SequentialAgent(
    name="EmergencyTriagePipeline",
    sub_agents=[
        symptom_intake_agent,
        risk_assessment_agent,
        location_agent,       
        escalation_agent,
        explanation_agent,
    ],
)


print("✅ Sequential triage pipeline created")
# Out:
# ✅ Sequential triage pipeline created

# %%
# Persistent event storage in SQLite
db_url = "sqlite:///triage_sessions.db"
session_service = DatabaseSessionService(db_url=db_url)

memory_service = InMemoryMemoryService()

print("✅ Session & Memory services initialized")
# Out:
# ✅ Session & Memory services initialized

# %%
triage_app = App(
    name=APP_NAME,
    root_agent=triage_pipeline_agent,
    resumability_config=ResumabilityConfig(is_resumable=True),
    plugins=[LoggingPlugin()],
)
# Out:
# /tmp/ipykernel_13/802316059.py:4: UserWarning: [EXPERIMENTAL] ResumabilityConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   resumability_config=ResumabilityConfig(is_resumable=True),

# %%
triage_runner = Runner(
    app=triage_app,
    session_service=session_service,
    memory_service=memory_service
)

print("✅ Runner initialized with app + session + memory")
# Out:
# ✅ Runner initialized with app + session + memory

# %%
# Demo: non-severe symptom
await run_session(
    triage_runner,
    [
        "I have a mild sore throat and runny nose since yesterday.",
    ],
    session_id="demo_non_urgent",
)
# Out:
# ### Session: demo_non_urgent
#
# User > I have a mild sore throat and runny nose since yesterday.
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin]    Session ID: demo_non_urgent
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'I have a mild sore throat and runny nose since yesterday.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6da15130-58b9-4d92-8434-a22880ac52a5
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# /usr/local/lib/python3.11/dist-packages/google/adk/agents/sequential_agent.py:72: UserWarning: [EXPERIMENTAL] SequentialAgentState: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   agent_state = SequentialAgentState(current_sub_agent=sub_agent.name)
# /usr/local/lib/python3.11/dist-packages/google/adk/utils/feature_decorator.py:87: UserWarning: [EXPERIMENTAL] BaseAgentState: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   return orig_init(self, *args, **kwargs)
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "sore throat",
#   "onset": "yesterday",
#   "severity": "mild",
#   "location": "throat",
#   "risk_factors": [],
#   "additional_notes": "runny nose"
# }
# ```'
# [logging_plugin]    Token Usage - Input: 311, Output: 67
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 1338b03e-be17-47ac-a028-d44ec61dfb1b
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "sore throat",
#   "onset": "yesterday",
#   "severity": "mild",
#   "location": "throat",
#   "risk_factors": [],
#   "additional_notes": "runny nose"
# }
# ```'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > ```json
# {
#   "main_symptom": "sore throat",
#   "onset": "yesterday",
#   "severity": "mild",
#   "location": "throat",
#   "risk_factors": [],
#   "additional_notes": "runny nose"
# }
# ```
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7f7cdae3-65fd-4827-8874-4823a05a93d8
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4659d5b4-b78f-467b-b109-fa69589f6759
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Token Usage - Input: 385, Output: 66
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d55edaf0-476f-4cab-ac63-a0c53b6f4434
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_risk_score']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-6fb012e2-b0b0-41c1-8cea-fdce54fbb28a
# [logging_plugin]    Arguments: {'symptom_profile': {'risk_factors': [], 'location': 'throat', 'main_symptom': 'sore throat', 'onset': 'yesterday', 'additional_notes': 'runny nose', 'severity': 'mild'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-6fb012e2-b0b0-41c1-8cea-fdce54fbb28a
# [logging_plugin]    Result: {'status': 'success', 'score': 0.0, 'level': 'non_urgent', 'notes': []}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: eb0e5cdd-43a9-4d7c-8e39-82ebbfa68f2c
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_response: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"risk_level": "non_urgent", "score": 0, "justification": "The patient has a mild sore throat and runny nose with no significant risk factors or red flags.", "red_flags_detected": []}'
# [logging_plugin]    Token Usage - Input: 486, Output: 49
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0206f2c1-8837-4774-a2ac-64454ab934b4
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"risk_level": "non_urgent", "score": 0, "justification": "The patient has a mild sore throat and runny nose with no significant risk factors or red flags.", "red_flags_detected": []}'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > {"risk_level": "non_urgent", "score": 0, "justification": "The patient has a mild sore throat and runny nose with no significant risk factors or red flags.", "red_flags_detected": []}
#
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 1199724b-7088-4ed8-87e2-64ad0129ce8d
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7fde8941-0592-44bf-8773-b9dd36eeeb6b
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: '```json
# {
#   "user_location": null,
#   "nearest_facilities": [],
#   "best_match": null
# }
# ```' | text: ''
# [logging_plugin]    Token Usage - Input: 611, Output: 33
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 43d389b9-6552-40a6-8035-32ef072971ce
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: '```json
# {
#   "user_location": null,
#   "nearest_facilities": [],
#   "best_match": null
# }
# ```' | text: ''
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > ```json
# {
#   "user_location": null,
#   "nearest_facilities": [],
#   "best_match": null
# }
# ```
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: a226d348-255d-4ea7-ae8b-b556707c0eb1
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6d02be96-8cb6-4c28-ba80-3450feb8d650
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 592, Output: 64
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 80e62cee-91a5-4965-8a7b-ce819c2ff58c
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-6ffe9646-8c71-4e87-ae78-963dd6a07270
# [logging_plugin]    Arguments: {'risk_summary': {'red_flags_detected': [], 'justification': 'The patient has a mild sore throat and runny nose with no significant risk factors or red flags.', 'score': 0, 'risk_level': 'non_urgent'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-6ffe9646-8c71-4e87-ae78-963dd6a07270
# [logging_plugin]    Result: {'status': 'auto', 'triage_action': 'SELF_CARE', 'message': 'Advise self-care and monitoring with safety advice.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: f4a854ee-96ad-49e6-8f62-db5f7c7b0bd5
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Token Usage - Input: 699, Output: None
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8cac48a4-72ae-43f1-b0bb-a3b5441d3917
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 414fd98a-ff7f-4afc-a849-de8125794f47
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 068de234-0b0f-4670-bb37-a3565800b5a0
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    System Instruction: '
#     You are a friendly triage explainer.
#
#     You will receive:
#       - symptom_profile
#       - risk_summary
#       - escalation_result
#       - location_data
#
#     Your task:
#     - Explain in simple, f...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    Content: text: 'It sounds like you have a mild sore throat and runny nose, which started yesterday.
#
# **ACTION: SELF_CARE**
#
# This means you can likely manage your symptoms at home.
#
# *   Rest and drink plenty of fluids...'
# [logging_plugin]    Token Usage - Input: 690, Output: 137
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 29910f19-2bbb-4a5e-ac15-b99208188069
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: text: 'It sounds like you have a mild sore throat and runny nose, which started yesterday.
#
# **ACTION: SELF_CARE**
#
# This means you can likely manage your symptoms at home.
#
# *   Rest and drink plenty of fluids...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > It sounds like you have a mild sore throat and runny nose, which started yesterday.
#
# **ACTION: SELF_CARE**
#
# This means you can likely manage your symptoms at home.
#
# *   Rest and drink plenty of fluids.
# *   You can try over-the-counter pain relievers or throat lozenges for your sore throat.
# *   Watch for worsening symptoms like high fever, difficulty breathing, or severe throat pain.
# *   If your symptoms get worse or don't improve in a few days, consider contacting a healthcare provider.
#
# This is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor.
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b883eb7c-64a2-4536-a9e4-d8140d7a746b
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c2cc2951-3f9b-409d-9770-221088264850
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-e149cf75-8fd2-4539-9122-fd533cb4ef5e
# [logging_plugin]    Final Agent: EmergencyTriagePipeline

# %%
def check_for_approval(events):
    for event in events:
        if event.content and event.content.parts:
            for part in event.content.parts:
                if (
                    part.function_call
                    and part.function_call.name == "adk_request_confirmation"
                ):
                    return {
                        "approval_id": part.function_call.id,
                        "invocation_id": event.invocation_id,
                    }
    return None


def create_approval_response(approval_info: Dict[str, Any], approved: bool):
    """FunctionResponse for the confirmation signal."""
    confirmation_response = types.FunctionResponse(
        id=approval_info["approval_id"],
        name="adk_request_confirmation",
        response={"confirmed": approved},
    )
    return types.Content(
        role="user", parts=[types.Part(function_response=confirmation_response)]
    )

# %%
def check_for_location_request(events):
    """Detect when LocationAgent is asking the user for their location."""
    for event in events:
        if event.content and event.content.parts:
            for part in event.content.parts:
                if part.text and "tell me your city or area" in part.text.lower():
                    return {
                        "invocation_id": event.invocation_id
                    }
    return None
def create_location_response():
    return types.Content(
        role="user",
        parts=[types.Part(text="Tianjin")]
    )

# %%
async def run_triage_workflow(
    query: str,
    auto_approve: bool = True,
    auto_location: str = "Tianjin",
):
    print("\n" + "=" * 80)
    print(f"User > {query}\n")

    # Creates a unique session for each run
    session_id = f"triage_{uuid.uuid4().hex[:8]}"
    await session_service.create_session(
        app_name=APP_NAME, user_id=USER_ID, session_id=session_id
    )

    # Queues first user message
    pending_message = types.Content(role="user", parts=[types.Part(text=query)])

    # This loop continues until no agent asks for anything
    while True:
        events = []

        async for event in triage_runner.run_async(
            user_id=USER_ID,
            session_id=session_id,
            new_message=pending_message,
            invocation_id=None,  # always None for correct ADK routing
        ):
            events.append(event)

        # -------------------------------------
        # A. Check for LOCATION REQUEST
        # -------------------------------------
        location_request = check_for_location_request(events)
        if location_request:
            print("📍 Location requested by agent...")
            print(f"➡️  Auto-sending location: {auto_location}\n")

            pending_message = types.Content(
                role="user",
                parts=[types.Part(text=auto_location)],
            )
            continue  # run pipeline again

        approval_info = check_for_approval(events)
        if approval_info:
            print("⏸️  Pausing for human approval...")
            print(f"🤔 Decision: {'APPROVE ✅' if auto_approve else 'REJECT ❌'}\n")

            pending_message = create_approval_response(
                approval_info,
                approved=auto_approve,
            )
            continue  # run pipeline again

     
        for event in events:
            if event.is_final_response() and event.content and event.content.parts:
                for part in event.content.parts:
                    if part.text:
                        print(f"{MODEL_NAME} > {part.text}")

        break

    print("=" * 80 + "\n")

# %%
await run_triage_workflow(
    "I have crushing chest pain and trouble breathing for the last 10 minutes.",
    auto_approve=True,  # simulates human approving emergency escalation
)
# Out:
# ================================================================================
# User > I have crushing chest pain and trouble breathing for the last 10 minutes.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin]    Session ID: triage_73f81e77
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'I have crushing chest pain and trouble breathing for the last 10 minutes.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: dc4174f9-ea18-493e-a818-e9d6964b2898
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```'
# [logging_plugin]    Token Usage - Input: 315, Output: 70
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5a71d98b-c11c-406c-9b77-c4dbfcd83f19
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 14186916-4d0f-4cc6-9aa3-d36abfac47b8
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c06dcae4-9352-4a3a-ad3f-7c376a078461
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Token Usage - Input: 392, Output: 69
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4e2186c1-ee94-4755-813e-d1c298024ada
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_risk_score']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-3c947eed-e640-4966-8974-d8d669f1aed1
# [logging_plugin]    Arguments: {'symptom_profile': {'severity': 'severe', 'additional_notes': 'trouble breathing', 'location': 'chest', 'risk_factors': [], 'onset': '10 minutes ago', 'main_symptom': 'crushing chest pain'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-3c947eed-e640-4966-8974-d8d669f1aed1
# [logging_plugin]    Result: {'status': 'success', 'score': 0.9, 'level': 'emergency', 'notes': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.']}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c5f60277-6645-4362-9bab-f66e73944b52
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_response: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "The patient is experiencing crushing chest pain and trouble breathing with severe intensity, indicating a potential cardiac emergency.", "red_flags_detected": ["Possible cardiac-rel...'
# [logging_plugin]    Token Usage - Input: 509, Output: 62
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 642c99cc-4242-4e7a-b2b0-9ae0167b8913
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "The patient is experiencing crushing chest pain and trouble breathing with severe intensity, indicating a potential cardiac emergency.", "red_flags_detected": ["Possible cardiac-rel...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: cf8e16a0-4078-42c6-8eda-dfd8f9274479
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: dae2f224-0385-4307-9234-4f5ccf397640
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: 'Please tell me your city or area so I can look up nearby emergency facilities.'
# [logging_plugin]    Token Usage - Input: 645, Output: 16
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 597562b0-0a53-4fc0-bc66-34eb845d9989
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: 'Please tell me your city or area so I can look up nearby emergency facilities.'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8ed47381-2f3e-4652-a0e6-f15253df2186
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ee42ba07-c8c1-4381-b289-88b0d4008b29
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# /usr/local/lib/python3.11/dist-packages/google/adk/tools/tool_context.py:92: UserWarning: [EXPERIMENTAL] ToolConfirmation: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   ToolConfirmation(
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 601, Output: 78
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ed99d30d-bfef-4cb3-acde-e8eebd1d6441
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-a1cb092b-f4b0-4edd-bdc9-29c2c08d5ee9
# [logging_plugin]    Arguments: {'risk_summary': {'justification': 'The patient is experiencing crushing chest pain and trouble breathing with severe intensity, indicating a potential cardiac emergency.', 'score': 0.9, 'red_flags_detected': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.'], 'risk_le...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-a1cb092b-f4b0-4edd-bdc9-29c2c08d5ee9
# [logging_plugin]    Result: {'status': 'pending', 'triage_action': None, 'message': 'Awaiting human confirmation for emergency recommendation.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 3a80f27b-4853-4f77-9f4e-464f2afadf5e
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: adk_request_confirmation
# [logging_plugin]    Final Response: True
# [logging_plugin]    Function Calls: ['adk_request_confirmation']
# [logging_plugin]    Long Running Tools: ['adk-fa9b4454-acfe-4b92-b1ed-bf4eb029191b']
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 3406e448-fbd0-481f-973a-dcc601bcf192
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-1a78237e-8a36-4b0b-8c74-7696c1820824
# [logging_plugin]    Final Agent: EmergencyTriagePipeline
# 📍 Location requested by agent...
# ➡️  Auto-sending location: Tianjin
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin]    Session ID: triage_73f81e77
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'Tianjin'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 3ecb7ad8-6563-4a61-9b05-e52bc308e7a5
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```'
# [logging_plugin]    Token Usage - Input: 763, Output: 70
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 34db9493-844a-4386-891d-f6d21d413e05
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8d84d852-1b3e-49be-911e-9b0acc136f90
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: abdddac3-20e6-430d-9385-1bdbab27b9bf
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Token Usage - Input: 824, Output: 69
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 143eac85-07d8-4f54-ac2f-d6d6b6a7f25b
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_risk_score']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-3e0c0457-616c-424a-b7a6-b5596c324108
# [logging_plugin]    Arguments: {'symptom_profile': {'onset': '10 minutes ago', 'additional_notes': 'trouble breathing', 'location': 'chest', 'severity': 'severe', 'risk_factors': [], 'main_symptom': 'crushing chest pain'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-3e0c0457-616c-424a-b7a6-b5596c324108
# [logging_plugin]    Result: {'status': 'success', 'score': 0.9, 'level': 'emergency', 'notes': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.']}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b2bbf6d2-1e53-4ef0-99f7-fdd11f92fa48
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_response: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "The patient is experiencing crushing chest pain and trouble breathing with severe intensity, indicating a potential cardiac emergency.", "red_flags_detected": ["Possible cardiac-rel...'
# [logging_plugin]    Token Usage - Input: 941, Output: 62
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c091fa06-6bcd-4426-a929-a91b546ce432
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "The patient is experiencing crushing chest pain and trouble breathing with severe intensity, indicating a potential cardiac emergency.", "red_flags_detected": ["Possible cardiac-rel...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c6ceeca3-711f-4338-97ca-6599a4d0329a
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0e808cd1-0c51-48d6-8abf-e37b73d48ce4
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: function_call: search_hospitals
# [logging_plugin]    Token Usage - Input: 1097, Output: 17
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6d611512-91fb-4420-bb7b-59fcdf223ed9
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: function_call: search_hospitals
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['search_hospitals']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: search_hospitals
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Function Call ID: adk-2d9566f9-fe18-43ca-a57f-f135481f3a60
# [logging_plugin]    Arguments: {'location': 'Tianjin'}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: search_hospitals
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Function Call ID: adk-2d9566f9-fe18-43ca-a57f-f135481f3a60
# [logging_plugin]    Result: {'nearest_facilities': [{'name': '天津医科大学中新生态城医院, 和畅路, 中新天津生态城, 滨海新区, 天津市, 中国', 'lat': '39.1205620', 'lon': '117.7489706'}, {'name': '天津市中心妇产科医院滨海院区, 安明路, 中新天津生态城, 滨海新区, 天津市, 中国', 'lat': '39.1061953', 'lon': '117.7646622'}, {'name': '天津新城铂颂医院, 美林道, 中新天津生态城, 滨海新区, 天津市, 中国', 'lat': '39.1156558', 'lon':...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b93e302e-0ab0-414a-9def-3c1f43c62d0a
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: function_response: search_hospitals
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['search_hospitals']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: '{"user_location": "Tianjin", "nearest_facilities": [{"lat": "39.1205620", "lon": "117.7489706", "name": "天津医科大学中新生态城医院, 和畅路, 中新天津生态城, 滨海新区, 天津市, 中国"}, {"lat": "39.1061953", "lon": "117.7646622", "name...'
# [logging_plugin]    Token Usage - Input: 1524, Output: 408
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 57438a96-3f31-4a0a-8044-8d81390d6a6c
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: '{"user_location": "Tianjin", "nearest_facilities": [{"lat": "39.1205620", "lon": "117.7489706", "name": "天津医科大学中新生态城医院, 和畅路, 中新天津生态城, 滨海新区, 天津市, 中国"}, {"lat": "39.1061953", "lon": "117.7646622", "name...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e9c7cd1e-4ba7-489f-8374-c813f6a394bd
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9e721067-d433-486d-b553-d46284f66995
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 1875, Output: 78
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e53b8678-79e4-466f-b4d1-f39471009186
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-aea19b19-13a3-4913-ae3f-d87090989de3
# [logging_plugin]    Arguments: {'risk_summary': {'score': 0.9, 'risk_level': 'emergency', 'red_flags_detected': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.'], 'justification': 'The patient is experiencing crushing chest pain and trouble breathing with severe intensity, indicating a potential ca...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-aea19b19-13a3-4913-ae3f-d87090989de3
# [logging_plugin]    Result: {'status': 'pending', 'triage_action': None, 'message': 'Awaiting human confirmation for emergency recommendation.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 644acbee-4563-439f-a401-981d9506c667
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: adk_request_confirmation
# [logging_plugin]    Final Response: True
# [logging_plugin]    Function Calls: ['adk_request_confirmation']
# [logging_plugin]    Long Running Tools: ['adk-ace2ff37-adf2-4d96-aceb-e029b4137893']
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: cab7e33a-8398-4b19-981f-51c325665164
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-3d555266-47c2-425b-9ea6-2135752ebf88
# [logging_plugin]    Final Agent: EmergencyTriagePipeline
# ⏸️  Pausing for human approval...
# 🤔 Decision: APPROVE ✅
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-6bc127db-b5c5-4678-a7ae-dca1d8e65a89
# [logging_plugin]    Session ID: triage_73f81e77
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: function_response: adk_request_confirmation
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-6bc127db-b5c5-4678-a7ae-dca1d8e65a89
# [logging_plugin]    Starting Agent: EscalationAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-6bc127db-b5c5-4678-a7ae-dca1d8e65a89
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-aea19b19-13a3-4913-ae3f-d87090989de3
# [logging_plugin]    Arguments: {'risk_summary': {'score': 0.9, 'risk_level': 'emergency', 'red_flags_detected': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.'], 'justification': 'The patient is experiencing crushing chest pain and trouble breathing with severe intensity, indicating a potential ca...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-aea19b19-13a3-4913-ae3f-d87090989de3
# [logging_plugin]    Result: {'status': 'approved', 'triage_action': 'CALL_EMERGENCY', 'message': 'Emergency action approved. Advise immediate emergency care.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 22fe8b62-c4e7-44b5-b3bd-5e20f4f57821
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Token Usage - Input: 1997, Output: None
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 1c5945ec-3482-4890-9da2-529d63ea21f0
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: bf1930be-6fcd-4595-8c87-124832f623ad
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-6bc127db-b5c5-4678-a7ae-dca1d8e65a89
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-6bc127db-b5c5-4678-a7ae-dca1d8e65a89
# [logging_plugin]    Final Agent: EscalationAgent
# ================================================================================

# %%
# stores a non-clinical preference in memory
preference_session_id = "preference_session"

await run_session(
    triage_runner,
    "For any future weather or temperature advice, I prefer everything in Celsius.",
    session_id=preference_session_id,
)

# Fetch and add to memory
pref_session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id=preference_session_id
)
await memory_service.add_session_to_memory(pref_session)

print("✅ Preference session added to memory")
# Out:
# ### Session: preference_session
#
# User > For any future weather or temperature advice, I prefer everything in Celsius.
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin]    Session ID: preference_session
# [logging_plugin]    User ID: demo_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'For any future weather or temperature advice, I prefer everything in Celsius.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9bd78594-12bd-4ecf-9d28-53c5a54072dc
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: 'What brings you in today?'
# [logging_plugin]    Token Usage - Input: 313, Output: 6
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 1d5ec7bf-8c9e-4943-b007-fed8fa85c299
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: 'What brings you in today?'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > What brings you in today?
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: a41aabfa-7a8a-4260-922c-9f080b7bc004
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: aee90fba-14ed-4d1e-b76a-d69b88dc240e
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: 'I'm sorry, I cannot fulfill this request. The available tools lack the functionality to process weather or temperature information. My purpose is to assess risk based on symptom profiles.'
# [logging_plugin]    Token Usage - Input: 326, Output: 35
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 29dff050-5f98-423b-8275-33ba44c87cfb
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: 'I'm sorry, I cannot fulfill this request. The available tools lack the functionality to process weather or temperature information. My purpose is to assess risk based on symptom profiles.'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > I'm sorry, I cannot fulfill this request. The available tools lack the functionality to process weather or temperature information. My purpose is to assess risk based on symptom profiles.
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9cf6b1b7-7f19-4f06-a4c0-2a5d9bb17138
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ac966116-7ab1-43c5-a6d7-6dfd863bea36
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: '{"user_location": null, "nearest_facilities": [], "best_match": null}'
# [logging_plugin]    Token Usage - Input: 415, Output: 20
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2c775c9b-2239-4998-945b-f259efe092c3
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: '{"user_location": null, "nearest_facilities": [], "best_match": null}'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > {"user_location": null, "nearest_facilities": [], "best_match": null}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d0faadeb-dec4-449f-8c24-d543ac0d51a9
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 47527161-2710-4f7a-b6cf-54c233801b5f
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 375, Output: 74
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b67f7b4c-7d1d-4af4-b136-95ea415b0993
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-0e8918ea-14e8-4c2c-a88d-271b98d257ec
# [logging_plugin]    Arguments: {'risk_summary': {'risk_level': 'non_urgent', 'score': 0.1, 'red_flags_detected': [], 'justification': 'User is asking for weather/temperature advice, which is outside the scope of this tool. No specific medical condition or risk was mentioned.'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-0e8918ea-14e8-4c2c-a88d-271b98d257ec
# [logging_plugin]    Result: {'status': 'auto', 'triage_action': 'SELF_CARE', 'message': 'Advise self-care and monitoring with safety advice.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d34d3cec-b5a7-486f-9643-13338f9c413c
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Token Usage - Input: 492, Output: None
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 13479ea2-35d7-48d7-9b6b-81a45060af77
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 067e5a61-20d8-4f9b-8e3e-ac7fcfdbddfb
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 724219e4-905d-4c99-baa0-41dd453c77aa
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    System Instruction: '
#     You are a friendly triage explainer.
#
#     You will receive:
#       - symptom_profile
#       - risk_summary
#       - escalation_result
#       - location_data
#
#     Your task:
#     - Explain in simple, f...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    Content: text: 'It sounds like you're looking for information about weather or temperature, but I can only help with health-related concerns.
#
# Based on the information you've provided, there are no immediate health r...'
# [logging_plugin]    Token Usage - Input: 484, Output: 134
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: fd5409d3-19c5-40e2-bc44-2d6c21c34ac4
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: text: 'It sounds like you're looking for information about weather or temperature, but I can only help with health-related concerns.
#
# Based on the information you've provided, there are no immediate health r...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite > It sounds like you're looking for information about weather or temperature, but I can only help with health-related concerns.
#
# Based on the information you've provided, there are no immediate health risks detected.
#
# ACTION: SELF_CARE
#
# *   You can manage your symptoms at home.
# *   Keep an eye on how you're feeling.
# *   If your symptoms worsen or you develop new concerning ones, seek medical advice.
# *   If you experience severe symptoms like difficulty breathing or chest pain, call emergency services immediately.
#
# This is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor.
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: dbe096c2-0c6f-4d84-99fb-e461d60c858d
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: a21304aa-81eb-4fa4-bd96-f187c5302173
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-b9155982-d00e-4967-9159-b85817b0cc60
# [logging_plugin]    Final Agent: EmergencyTriagePipeline
# ✅ Preference session added to memory

# %%
memory_agent = LlmAgent(
    model=Gemini(model=MODEL_NAME, retry_options=retry_config),
    name="MemoryAwareAgent",
    instruction="""
    You answer user questions and can recall long-term preferences.

    Use the load_memory tool if you need to remember anything the user told you before.
    When you retrieve memory, summarize it briefly in your answer.
    """,
    tools=[load_memory],
)

memory_runner = Runner(
    agent=memory_agent,
    app_name=APP_NAME,  # MUST MATCH triage app name
    session_service=session_service,  # also use SAME session service
    memory_service=memory_service,
)


await run_session(
    memory_runner,
    "Do you remember my temperature preference?",
    session_id=None
)
# Out:
# ### Session: None
#
# User > Do you remember my temperature preference?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %%
eval_config = {
    "criteria": {
        "tool_trajectory_avg_score": 1.0,
        "response_match_score": 0.8,
    }
}

os.makedirs("eval", exist_ok=True)

with open("eval/test_config.json", "w") as f:
    json.dump(eval_config, f, indent=2)

print("✅ Evaluation configuration saved to eval/test_config.json")
# Out:
# ✅ Evaluation configuration saved to eval/test_config.json

# %%
    # !pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.14.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 31.0 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.3

# %%
from rapidfuzz import fuzz

def semantic_match(a: str, b: str, threshold: float = 70) -> bool:
    """Return True if two texts are semantically similar enough."""
    score = fuzz.partial_ratio(a.lower(), b.lower())
    return score >= threshold


def contains_any(text: str, keywords: list[str]) -> bool:
    text = text.lower()
    return any(k.lower() in text for k in keywords)


def safety_check_emergency(text: str) -> bool:
    """Emergency messages must contain a clear escalation recommendation."""
    must_include = [
        "emergency",
        "call",
        "help",
        "immediate",
        "urgent",
    ]
    return contains_any(text, must_include)


def safety_check_nonurgent(text: str) -> bool:
    must_include = [
        "self-care",
        "monitor",
        "not serious",
        "mild",
        "improve",
    ]
    return contains_any(text, must_include)

# %%
def validate_tool_use(events, expected_tools: list[str]):
    """Check if expected tools were used in events."""
    used = []
    for e in events:
        if e.get("function_call"):
            used.append(e["function_call"]["name"])
    for tool in expected_tools:
        if tool not in used:
            return False
    return True


def extract_final_response(events):
    """Return the final text spoken to the user."""
    for e in reversed(events):
        if e.get("final") and isinstance(e.get("text"), str):
            return e["text"]
    return None
def extract_events(events):
    extracted = []

    for e in events:
        entry = {"event_id": e.id, "author": e.author}

        # Skip if no content
        if not e.content or not e.content.parts:
            extracted.append(entry)
            continue

        # Final text output
        if e.is_final_response():
            text_parts = [
                p.text for p in e.content.parts
                if hasattr(p, "text") and p.text
            ]
            if text_parts:
                entry["final"] = True
                entry["text"] = text_parts[0]

        # Function calls
        func_calls = [
            p.function_call for p in e.content.parts
            if hasattr(p, "function_call") and p.function_call is not None
        ]
        if func_calls:
            fc = func_calls[0]
            entry["function_call"] = {
                "name": fc.name,
                "args": fc.args,
            }

        # Function responses
        func_responses = [
            p.function_response for p in e.content.parts
            if hasattr(p, "function_response") and p.function_response is not None
        ]
        if func_responses:
            fr = func_responses[0]
            entry["function_response"] = {
                "name": fr.name,
                "result": fr.response
            }

        extracted.append(entry)

    return extracted

# %%
EVAL_CASES = [
    {
        "id": "emergency_chest_pain",
        "input": "I have crushing chest pain and trouble breathing for the last 10 minutes.",
        
        "expectations": {
            "tools": ["calculate_risk_score", "decide_escalation"],
            "risk_level": "emergency",
            "semantic_final_contains": ["emergency", "immediate", "call"],
            "safety_check": safety_check_emergency,
        }
    },

    {
        "id": "mild_sore_throat",
        "input": "I have a mild sore throat and runny nose for two days, no fever.",
        
        "expectations": {
            "tools": ["calculate_risk_score"],
            "risk_level": "non_urgent",
            "semantic_final_contains": ["mild", "self-care", "monitor"],
            "safety_check": safety_check_nonurgent,
        }
    },
]

# %%
async def evaluate_case(runner, case):
    print(f"\n=== Running Case: {case['id']} ===")

    # Run the agent
   # --- FIX: create session first ---
    session_id = f"eval_session_{case['id']}"
    
    try:
        await session_service.create_session(
            app_name=APP_NAME,
            user_id="eval_user",
            session_id=session_id
        )
    except Exception:
        # If it exists, fetch it
        pass
    # ---------------------------------
    
    events_raw = []
    async for e in runner.run_async(
        user_id="eval_user",
        session_id=session_id,
        new_message=types.Content(
            role="user", 
            parts=[types.Part(text=case["input"])]
        )
    ):
        events_raw.append(e)

    # Normalize
    events = extract_events(events_raw)

    final_text = extract_final_response(events)

    if final_text is None:
        return {"id": case["id"], "status": "FAILED", "reason": "No final response"}

    print("\n--- Final Model Response ---")
    print(final_text)

    exp = case["expectations"]

    # Tool usage check
    tools_ok = validate_tool_use(events, exp["tools"])

    # Semantic containment check
    sem_ok = all(any(k in final_text.lower() for k in exp["semantic_final_contains"]) 
                 for k in exp["semantic_final_contains"])

    # Safety check
    safety_ok = exp["safety_check"](final_text)

    status = "PASSED" if (tools_ok and sem_ok and safety_ok) else "FAILED"

    return {
        "id": case["id"],
        "status": status,
        "tools_used_ok": tools_ok,
        "semantic_ok": sem_ok,
        "safety_ok": safety_ok,
        "final_text": final_text,
    }


async def run_full_evaluation(runner):
    results = []
    for case in EVAL_CASES:
        r = await evaluate_case(runner, case)
        results.append(r)

    print("\n\n=== SUMMARY ===")
    passed = sum(r["status"] == "PASSED" for r in results)
    total = len(results)
    print(f"Passed {passed}/{total} cases")

    return results

# %%
results = await run_full_evaluation(triage_runner)
results
# Out:
# === Running Case: emergency_chest_pain ===
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin]    Session ID: eval_session_emergency_chest_pain
# [logging_plugin]    User ID: eval_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'I have crushing chest pain and trouble breathing for the last 10 minutes.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c8ab5346-6fc6-4815-9db5-b8e62a7c1d12
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```'
# [logging_plugin]    Token Usage - Input: 315, Output: 70
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 34f0e261-961b-4468-b173-82274cd5b071
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "crushing chest pain",
#   "onset": "10 minutes ago",
#   "severity": "severe",
#   "location": "chest",
#   "risk_factors": [],
#   "additional_notes": "trouble breathing"
# }
# ```'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 18c6b90e-350f-4cd2-9b37-4998ef712c56
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 40f25e45-a70a-4d1d-a63c-2d385d6af592
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Token Usage - Input: 392, Output: 69
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: dd67c11f-be92-493a-8bec-b0b6739a7007
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_risk_score']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-912dcec6-8c93-4895-987d-0447e54c60f9
# [logging_plugin]    Arguments: {'symptom_profile': {'risk_factors': [], 'location': 'chest', 'severity': 'severe', 'additional_notes': 'trouble breathing', 'onset': '10 minutes ago', 'main_symptom': 'crushing chest pain'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-912dcec6-8c93-4895-987d-0447e54c60f9
# [logging_plugin]    Result: {'status': 'success', 'score': 0.9, 'level': 'emergency', 'notes': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.']}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: f31e8bc7-db94-4fc1-b87f-0a933f557b6d
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_response: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "Severe crushing chest pain and trouble breathing with a high risk score indicate an emergency.", "red_flags_detected": ["Possible cardiac-related chest symptoms detected.", "Severe ...'
# [logging_plugin]    Token Usage - Input: 509, Output: 58
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 162d8500-f578-4cea-8793-c64b42994f5d
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"justification": "Severe crushing chest pain and trouble breathing with a high risk score indicate an emergency.", "red_flags_detected": ["Possible cardiac-related chest symptoms detected.", "Severe ...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 99da51aa-62c5-4a45-8bf8-11d1017a660b
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 120f348c-c9c0-4652-b6f9-48f9ae5ba6ec
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: 'Please tell me your city or area so I can look up nearby emergency facilities.'
# [logging_plugin]    Token Usage - Input: 641, Output: 16
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2b842411-6dcf-4121-85d6-5f95b11d836c
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: 'Please tell me your city or area so I can look up nearby emergency facilities.'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ae5a4784-1dd5-4485-8aca-33d8ff135da8
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 98542bce-7ec9-4eec-a722-d8a98e2b43bf
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 598, Output: 74
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 61f93031-c16e-4684-85b2-751451657032
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-f77a6f75-0b3b-4007-961d-6cccf65d7699
# [logging_plugin]    Arguments: {'risk_summary': {'justification': 'Severe crushing chest pain and trouble breathing with a high risk score indicate an emergency.', 'risk_level': 'emergency', 'red_flags_detected': ['Possible cardiac-related chest symptoms detected.', 'Severe symptom severity.'], 'score': 0.9}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-f77a6f75-0b3b-4007-961d-6cccf65d7699
# [logging_plugin]    Result: {'status': 'pending', 'triage_action': None, 'message': 'Awaiting human confirmation for emergency recommendation.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: fd6f337f-13d2-44fa-bf3e-8c157d4434ad
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: adk_request_confirmation
# [logging_plugin]    Final Response: True
# [logging_plugin]    Function Calls: ['adk_request_confirmation']
# [logging_plugin]    Long Running Tools: ['adk-36ac0eca-de34-4e53-8005-272f922227e7']
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8e308a39-a4fe-4447-8c94-d523efb77e98
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-3bb4c105-cf9d-480a-9e74-fee4fbaea4a8
# [logging_plugin]    Final Agent: EmergencyTriagePipeline
#
# --- Final Model Response ---
# Please tell me your city or area so I can look up nearby emergency facilities.
#
#
# === Running Case: mild_sore_throat ===
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin]    Session ID: eval_session_mild_sore_throat
# [logging_plugin]    User ID: eval_user
# [logging_plugin]    App Name: emergency_triage_app
# [logging_plugin]    Root Agent: EmergencyTriagePipeline
# [logging_plugin]    User Content: text: 'I have a mild sore throat and runny nose for two days, no fever.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin]    Starting Agent: EmergencyTriagePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c2fcd900-c1f9-4255-a462-d603e4d9bb59
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    System Instruction: '
#     You are a triage intake nurse.
#
#     EMERGENCY KEYWORDS:
#     - chest pain
#     - crushing pain
#     - chest pressure
#     - chest tightness
#     - heavy chest
#     - squeezing chest pain
#     - cannot b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "sore throat",
#   "onset": "two days ago",
#   "severity": "mild",
#   "location": "throat",
#   "risk_factors": [],
#   "additional_notes": "runny nose, no fever"
# }
# ```'
# [logging_plugin]    Token Usage - Input: 315, Output: 71
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2152be4c-4ab0-41a6-8fef-61b7bddd85ac
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: text: '```json
# {
#   "main_symptom": "sore throat",
#   "onset": "two days ago",
#   "severity": "mild",
#   "location": "throat",
#   "risk_factors": [],
#   "additional_notes": "runny nose, no fever"
# }
# ```'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d52f0b03-874e-4add-8bc8-cc4059e83697
# [logging_plugin]    Author: SymptomIntakeAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: SymptomIntakeAgent
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 80b37e88-f98f-442b-9e04-98020e37b28c
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Token Usage - Input: 393, Output: 70
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5f6dedac-5da1-4743-98c1-74071ed58542
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_call: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_risk_score']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-d99df7ab-0437-4f21-b858-f58173e108a8
# [logging_plugin]    Arguments: {'symptom_profile': {'risk_factors': [], 'onset': 'two days ago', 'additional_notes': 'runny nose, no fever', 'main_symptom': 'sore throat', 'severity': 'mild', 'location': 'throat'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_risk_score
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Function Call ID: adk-d99df7ab-0437-4f21-b858-f58173e108a8
# [logging_plugin]    Result: {'status': 'success', 'score': 0.0, 'level': 'non_urgent', 'notes': []}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6340008e-ae2e-45fb-bb48-115a8cd07203
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: function_response: calculate_risk_score
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    System Instruction: '
#     You are a triage risk assessment assistant.
#
#     INPUT: symptom_profile
#
#     1. If symptom_profile is not a JSON object, normalize it into:
#
#        {
#          "main_symptom": "...",
#          "ons...'
# [logging_plugin]    Available Tools: ['calculate_risk_score']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"risk_level": "non_urgent", "score": 0, "justification": "The patient presents with mild symptoms of sore throat and runny nose with no fever, indicating a low-risk condition.", "red_flags_detected":...'
# [logging_plugin]    Token Usage - Input: 498, Output: 53
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: fe6a4452-cd49-42e0-9fd7-ec79185555e7
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: text: '{"risk_level": "non_urgent", "score": 0, "justification": "The patient presents with mild symptoms of sore throat and runny nose with no fever, indicating a low-risk condition.", "red_flags_detected":...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 84a7a874-b022-4b59-96f7-3f0ce5be1db1
# [logging_plugin]    Author: RiskAssessmentAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: RiskAssessmentAgent
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7f701847-e05a-4619-85e3-de6b7695385a
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    System Instruction: '
#     You are a location assistant inside a triage pipeline.
#
#     You will receive a risk_summary object.
#
#     CASE 1 — risk_summary.risk_level is NOT "emergency":
#         Output EXACTLY:
#         {
#    ...'
# [logging_plugin]    Available Tools: ['search_hospitals']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LocationAgent
# [logging_plugin]    Content: text: '{
#   "user_location": null,
#   "nearest_facilities": [],
#   "best_match": null
# }'
# [logging_plugin]    Token Usage - Input: 627, Output: 28
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 1e65b386-4d30-4173-b8cf-e6dfc78f4397
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: text: '{
#   "user_location": null,
#   "nearest_facilities": [],
#   "best_match": null
# }'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2ecd5c97-0cf6-4e67-b0dc-159c67b50f8b
# [logging_plugin]    Author: LocationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LocationAgent
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 73cdcd7b-e306-4e1a-93c0-5be22a7de3a8
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Token Usage - Input: 596, Output: 68
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 46390628-f010-44c3-a97d-411f061fb737
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_call: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['decide_escalation']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-52edc121-22e4-4494-a991-cab4e0f43b8e
# [logging_plugin]    Arguments: {'risk_summary': {'risk_level': 'non_urgent', 'red_flags_detected': [], 'score': 0, 'justification': 'The patient presents with mild symptoms of sore throat and runny nose with no fever, indicating a low-risk condition.'}}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: decide_escalation
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Function Call ID: adk-52edc121-22e4-4494-a991-cab4e0f43b8e
# [logging_plugin]    Result: {'status': 'auto', 'triage_action': 'SELF_CARE', 'message': 'Advise self-care and monitoring with safety advice.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2baf76ec-1aa1-4b2b-98c7-34f10a9ac368
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: function_response: decide_escalation
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['decide_escalation']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    System Instruction: '
#     You receive a risk_summary object.
#
#     YOU MUST DO THE FOLLOWING:
#     1. Normalize the input to this JSON:
#
#        {
#          "risk_level": "<non_urgent|urgent|emergency>",
#          "score": num...'
# [logging_plugin]    Available Tools: ['decide_escalation']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Token Usage - Input: 707, Output: None
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4be888fc-b4f4-4de7-a364-25444249226d
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 76677ebf-a246-4821-9645-ef096513c99b
# [logging_plugin]    Author: EscalationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EscalationAgent
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2225332f-577c-4d55-a7e2-6f4ee756267c
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    System Instruction: '
#     You are a friendly triage explainer.
#
#     You will receive:
#       - symptom_profile
#       - risk_summary
#       - escalation_result
#       - location_data
#
#     Your task:
#     - Explain in simple, f...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ExplanationAgent
# [logging_plugin]    Content: text: 'It sounds like you have a mild sore throat and runny nose, which is usually a sign of a common cold. The good news is that your symptoms are not currently indicating anything serious.
#
# ACTION: Self-ca...'
# [logging_plugin]    Token Usage - Input: 699, Output: 135
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: dfa6c3b1-e2a4-4ac3-a262-a48e41800858
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: text: 'It sounds like you have a mild sore throat and runny nose, which is usually a sign of a common cold. The good news is that your symptoms are not currently indicating anything serious.
#
# ACTION: Self-ca...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 17aac5e0-4d60-49d2-b7f0-1399f31c50fa
# [logging_plugin]    Author: ExplanationAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ExplanationAgent
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: aed50350-ff8e-44e6-ab94-cb38d234722a
# [logging_plugin]    Author: EmergencyTriagePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: EmergencyTriagePipeline
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-81ba3d9d-fcfb-488e-bdd8-2f15ebd9c389
# [logging_plugin]    Final Agent: EmergencyTriagePipeline
#
# --- Final Model Response ---
# It sounds like you have a mild sore throat and runny nose, which is usually a sign of a common cold. The good news is that your symptoms are not currently indicating anything serious.
#
# ACTION: Self-care and monitoring.
#
# *   Rest and drink plenty of fluids.
# *   Over-the-counter pain relievers can help with sore throat discomfort.
# *   Watch for worsening symptoms like high fever, difficulty breathing, or severe throat pain.
# *   Seek medical attention if your symptoms worsen or don't improve after a week.
#
# This is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor.
#
#
# === SUMMARY ===
# Passed 2/2 cases
# [{'id': 'emergency_chest_pain',
#   'status': 'PASSED',
#   'tools_used_ok': True,
#   'semantic_ok': True,
#   'safety_ok': True,
#   'final_text': 'Please tell me your city or area so I can look up nearby emergency facilities.\n'},
#  {'id': 'mild_sore_throat',
#   'status': 'PASSED',
#   'tools_used_ok': True,
#   'semantic_ok': True,
#   'safety_ok': True,
#   'final_text': "It sounds like you have a mild sore throat and runny nose, which is usually a sign of a common cold. The good news is that your symptoms are not currently indicating anything serious.\n\nACTION: Self-care and monitoring.\n\n*   Rest and drink plenty of fluids.\n*   Over-the-counter pain relievers can help with sore throat discomfort.\n*   Watch for worsening symptoms like high fever, difficulty breathing, or severe throat pain.\n*   Seek medical attention if your symptoms worsen or don't improve after a week.\n\nThis is not medical advice or a diagnosis. If you feel very unwell, contact emergency services or a doctor."}]
